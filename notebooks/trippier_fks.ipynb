# %%
### IMPORTS ###

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests 
from bs4 import BeautifulSoup
import json
from pprint import pprint
import matplotlib.image as mpimg
import matplotlib.patches as patches
from PIL import Image
from io import BytesIO
#from highlight_text import htext
import matplotlib as mpl
from matplotlib.gridspec import GridSpec
from mplsoccer.pitch import Pitch, VerticalPitch

from matplotlib import font_manager
#font_manager.findSystemFonts(fontpaths=None, fontext="ttf")

# %%
### URL ###

base_url = 'https://understat.com/player/'
player = '2097'       # Messi 2097
url = base_url + player

# %%
### SCRAPE ###

res = requests.get(url)
soup = BeautifulSoup(res.content,'lxml')
scripts = soup.find_all('script')

# %%
scripts
# Out:
# [<script>
#  			var THEME = localStorage.getItem("theme") || 'DARK';
#  			document.body.className = "theme-" + THEME.toLowerCase();
#  		</script>,
#  <script>
#  	var groupsData 		= JSON.parse('\x7B\x22season\x22\x3A\x5B\x7B\x22position\x22\x3A\x22FW\x22,\x22games\x22\x3A\x2232\x22,\x22goals\x22\x3A\x2216\x22,\x22shots\x22\x3A\x22129\x22,\x22time\x22\x3A\x222855\x22,\x22xG\x22\x3A\x2217.663388540036976\x22,\x22assists\x22\x3A\x2216\x22,\x22xA\x22\x3A\x2215.239965826272964\x22,\x22key_passes\x22\x3A\x2293\x22,\x22season\x22\x3A\x222022\x22,\x22team\x22\x3A\x22Paris\x20Saint\x20Germain\x22,\x22yellow\x22\x3A\x220\x22,\x22red\x22\x3A\x220\x22,\x22npg\x22\x3A\x2216\x22,\x22npxG\x22\x3A\x2217.663388540036976\x22,\x22xGChain\x22\x3A\x2239.00348609033972\x22,\x22xGBuildup\x22\x3A\x2215.89331340789795\x22\x7D,\x7B\x22position\x22\x3A\x22Sub\x22,\x22games\x22\x3A\x2226\x22,\x22goals\x22\x3A\x226\x22,\x22shots\x22\x3A\x2289\x22,\x22time\x22\x3A\x222155\x22,\x22xG\x22\x3A\x229.880364246666431\x22,\x22assists\x22\x3A\x2213\x22,\x22xA\x22\x3A\x228.68060227110982\x22,\x22key_passes\x22\x3A\x2263\x22,\x22season\x22\x3A\x222021\x22,\x22team\x22\x3A\x22Paris\x20Saint\x20Germain\x22,\x22yellow\x22\x3A\x220\x22,\x22red\x22\x3A\x220\x22,\x22npg\x22\x3A\x226\x22,\x22npxG\x22\x3A\x229.880364246666431\x22,\x22xGChain\x22\x3A\x2227.21941590309143\x22,\x22xGBuildup\x22\x3A\x2213.841111708432436\x22\x7D,\x7B\x22position\x22\x3A\x22FW\x22,\x22games\x22\x3A\x2235\x22,\x22goals\x22\x3A\x2230\x22,\x22shots\x22\x3A\x22195\x22,\x22time\x22\x3A\x223017\x22,\x22xG\x22\x3A\x2226.676853142678738\x22,\x22assists\x22\x3A\x229\x22,\x22xA\x22\x3A\x2211.422849107533693\x22,\x22key_passes\x22\x3A\x2277\x22,\x22season\x22\x3A\x222020\x22,\x22team\x22\x3A\x22Barcelona\x22,\x22yellow\x22\x3A\x224\x22,\x22red\x22\x3A\x220\x22,\x22npg\x22\x3A\x2227\x22,\x22npxG\x22\x3A\x2222.960455916821957\x22,\x22xGChain\x22\x3A\x2237.906861275434494\x22,\x22xGBuildup\x22\x3A\x2220.33736425638199\x22\x7D,\x7B\x22position\x22\x3A\x22Sub\x22,\x22games\x22\x3A\x2233\x22,\x22goals\x22\x3A\x2225\x22,\x22shots\x22\x3A\x22159\x22,\x22time\x22\x3A\x222876\x22,\x22xG\x22\x3A\x2220.849658865481615\x22,\x22assists\x22\x3A\x2220\x22,\x22xA\x22\x3A\x2216.593371644616127\x22,\x22key_passes\x22\x3A\x2288\x22,\x22season\x22\x3A\x222019\x22,\x22team\x22\x3A\x22Barcelona\x22,\x22yellow\x22\x3A\x224\x22,\x22red\x22\x3A\x220\x22,\x22npg\x22\x3A\x2220\x22,\x22npxG\x22\x3A\x2217.133270878344774\x22,\x22xGChain\x22\x3A\x2234.92347752302885\x22,\x22xGBuildup\x22\x3A\x2213.537661855109036\x22\x7D,\x7B\x22position\x22\x3A\x22FW\x22,\x22games\x22\x3A\x2234\x22,\x22goals\x22\x3A\x2236\x22,\x22shots\x22\x3A\x22170\x22,\x22time\x22\x3A\x222704\x22,\x22xG\x22\x3A\x2225.997147038578987\x22,\x22assists\x22\x3A\x2213\x22,\x22xA\x22\x3A\x2215.335163585841656\x22,\x22key_passes\x22\x3A\x2293\x22,\x22season\x22\x3A\x222018\x22,\x22team\x22\x3A\x22Barcelona\x22,\x22yellow\x22\x3A\x223\x22,\x22red\x22\x3A\x220\x22,\x22npg\x22\x3A\x2232\x22,\x22npxG\x22\x3A\x2222.280887201428413\x22,\x22xGChain\x22\x3A\x2238.45986612141132\x22,\x22xGBuildup\x22\x3A\x2210.698799947276711\x22\x7D,\x7B\x22position\x22\x3A\x22FW\x22,\x22games\x22\x3A\x2236\x22,\x22goals\x22\x3A\x2234\x22,\x22shots\x22\x3A\x22196\x22,\x22time\x22\x3A\x222995\x22,\x22xG\x22\x3A\x2228.946291390806437\x22,\x22assists\x22\x3A\x2212\x22,\x22xA\x22\x3A\x2215.100405801087618\x22,\x22key_passes\x22\x3A\x2287\x22,\x22season\x22\x3A\x222017\x22,\x22team\x22\x3A\x22Barcelona\x22,\x22yellow\x22\x3A\x223\x22,\x22red\x22\x3A\x220\x22,\x22npg\x22\x3A\x2232\x22,\x22npxG\x22\x3A\x2225.973176393657923\x22,\x22xGChain\x22\x3A\x2248.18063086271286\x22,\x22xGBuildup\x22\x3A\x2221.63439449854195\x22\x7D,\x7B\x22position\x22\x3A\x22FWR\x22,\x22games\x22\x3A\x2234\x22,\x22goals\x22\x3A\x2237\x22,\x22shots\x22\x3A\x22179\x22,\x22time\x22\x3A\x222832\x22,\x22xG\x22\x3A\x2226.88517417013645\x22,\x22assists\x22\x3A\x229\x22,\x22xA\x22\x3A\x2213.955131754279137\x22,\x22key_passes\x22\x3A\x2279\x22,\x22season\x22\x3A\x222016\x22,\x22team\x22\x3A\x22Barcelona\x22,\x22yellow\x22\x3A\x226\x22,\x22red\x22\x3A\x220\x22,\x22npg\x22\x3A\x2231\x22,\x22npxG\x22 ...
#  		avgPlayerStats 	= JSON.parse('null');
#  </script>,
#  <script>
#  	var minMaxPlayerStats 	= JSON.parse('\x7B\x22AMC\x22\x3A\x7B\x22goals\x22\x3A\x7B\x22min\x22\x3A0.0002999999999999999737189393389513725196593441069126129150390625,\x22max\x22\x3A0.006199999999999999782118731417313028941862285137176513671875,\x22avg\x22\x3A0.0022999999999999999611421941381195210851728916168212890625\x7D,\x22xG\x22\x3A\x7B\x22min\x22\x3A0.000660038000000000052609749889853674176265485584735870361328125,\x22max\x22\x3A0.0049826399999999999856914456586309825070202350616455078125,\x22avg\x22\x3A0.0021921499999999999146182982912023362587206065654754638671875\x7D,\x22shots\x22\x3A\x7B\x22min\x22\x3A0.01110000000000000049127368839663176913745701313018798828125,\x22max\x22\x3A0.042500000000000003053113317719180486164987087249755859375,\x22avg\x22\x3A0.02179999999999999993338661852249060757458209991455078125\x7D,\x22assists\x22\x3A\x7B\x22min\x22\x3A0.0002999999999999999737189393389513725196593441069126129150390625,\x22max\x22\x3A0.0057999999999999996003197111349436454474925994873046875,\x22avg\x22\x3A0.0017999999999999999507338532822586785187013447284698486328125\x7D,\x22xA\x22\x3A\x7B\x22min\x22\x3A0.00071177700000000002598932180575275197043083608150482177734375,\x22max\x22\x3A0.004592549999999999930933025638069011620245873928070068359375,\x22avg\x22\x3A0.0018425799999999999123634353281886433251202106475830078125\x7D,\x22key_passes\x22\x3A\x7B\x22min\x22\x3A0.00899999999999999931998839741709161899052560329437255859375,\x22max\x22\x3A0.0451000000000000011990408665951690636575222015380859375,\x22avg\x22\x3A0.018599999999999998478994456263535539619624614715576171875\x7D,\x22xGChain\x22\x3A\x7B\x22min\x22\x3A0.00274982999999999998264055278696105233393609523773193359375,\x22max\x22\x3A0.01007060000000000073161476876748565700836479663848876953125,\x22avg\x22\x3A0.00488010000000000006281641873329135705716907978057861328125\x7D,\x22xGBuildup\x22\x3A\x7B\x22min\x22\x3A0.00107182000000000002097599871575539509649388492107391357421875,\x22max\x22\x3A0.006206429999999999759519031528043342404998838901519775390625,\x22avg\x22\x3A0.002220719999999999812179130032063767430372536182403564453125\x7D\x7D,\x22AMR\x22\x3A\x7B\x22goals\x22\x3A\x7B\x22min\x22\x3A0.000699999999999999992887633748495090912911109626293182373046875,\x22max\x22\x3A0.00549999999999999968081088042026749462820589542388916015625,\x22avg\x22\x3A0.00200000000000000004163336342344337026588618755340576171875\x7D,\x22xG\x22\x3A\x7B\x22min\x22\x3A0.000999218999999999975270004171079563093371689319610595703125,\x22max\x22\x3A0.004491760000000000023490098755019062082283198833465576171875,\x22avg\x22\x3A0.001965399999999999959554575212905547232367098331451416015625\x7D,\x22shots\x22\x3A\x7B\x22min\x22\x3A0.01230000000000000016930901125533637241460382938385009765625,\x22max\x22\x3A0.036200000000000003008704396734174224548041820526123046875,\x22avg\x22\x3A0.020099999999999999811262085813723388127982616424560546875\x7D,\x22assists\x22\x3A\x7B\x22min\x22\x3A0.0015000000000000000312250225675825276994146406650543212890625,\x22max\x22\x3A0.004499999999999999659994198708545809495262801647186279296875,\x22avg\x22\x3A0.0017999999999999999507338532822586785187013447284698486328125\x7D,\x22xA\x22\x3A\x7B\x22min\x22\x3A0.0014268200000000000847444336926628238870762288570404052734375,\x22max\x22\x3A0.004444509999999999606823397613197812461294233798980712890625,\x22avg\x22\x3A0.0018128499999999999649225035369681791053153574466705322265625\x7D,\x22key_passes\x22\x3A\x7B\x22min\x22\x3A0.0120999999999999996447286321199499070644378662109375,\x22max\x22\x3A0.036499999999999997724042799518429092131555080413818359375,\x22avg\x22\x3A0.01650000000000000077715611723760957829654216766357421875\x7D,\x22xGChain\x22\x3A\x7B\x22min\x22\x3A0.003828390000000000091551211056639658636413514614105224609375,\x22max\x22\x3A0.0090586999999999993915533735844292095862329006195068359375,\x22avg\x22\x3A0.004553670000000000113449249994346246239729225635528564453125\x7D,\x22xGBuildup\x22\x3A\x7B\x22min\x22\x3A0.00109595999 ...
#  		positionsList		= JSON.parse('\x5B\x22GK\x22,\x22DR\x22,\x22DC\x22,\x22DL\x22,\x22DMR\x22,\x22DML\x22,\x22DMC\x22,\x22MR\x22,\x22MC\x22,\x22ML\x22,\x22AMR\x22,\x22AMC\x22,\x22AML\x22,\x22FWR\x22,\x22FW\x22,\x22FWL\x22,\x22Sub\x22\x5D');
#  </script>,
#  <script>
#  	var shotsData 	= JSON.parse('\x5B\x7B\x22id\x22\x3A\x2232522\x22,\x22minute\x22\x3A\x2222\x22,\x22result\x22\x3A\x22MissedShots\x22,\x22X\x22\x3A\x220.7859999847412109\x22,\x22Y\x22\x3A\x220.52\x22,\x22xG\x22\x3A\x220.03867039829492569\x22,\x22player\x22\x3A\x22Lionel\x20Messi\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x222097\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222014\x22,\x22shotType\x22\x3A\x22LeftFoot\x22,\x22match_id\x22\x3A\x225831\x22,\x22h_team\x22\x3A\x22Barcelona\x22,\x22a_team\x22\x3A\x22Elche\x22,\x22h_goals\x22\x3A\x223\x22,\x22a_goals\x22\x3A\x220\x22,\x22date\x22\x3A\x222014\x2D08\x2D24\x2020\x3A00\x3A00\x22,\x22player_assisted\x22\x3A\x22Rafinha\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x2232525\x22,\x22minute\x22\x3A\x2241\x22,\x22result\x22\x3A\x22Goal\x22,\x22X\x22\x3A\x220.8619999694824219\x22,\x22Y\x22\x3A\x220.615\x22,\x22xG\x22\x3A\x220.06870149821043015\x22,\x22player\x22\x3A\x22Lionel\x20Messi\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x222097\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222014\x22,\x22shotType\x22\x3A\x22LeftFoot\x22,\x22match_id\x22\x3A\x225831\x22,\x22h_team\x22\x3A\x22Barcelona\x22,\x22a_team\x22\x3A\x22Elche\x22,\x22h_goals\x22\x3A\x223\x22,\x22a_goals\x22\x3A\x220\x22,\x22date\x22\x3A\x222014\x2D08\x2D24\x2020\x3A00\x3A00\x22,\x22player_assisted\x22\x3A\x22Sergio\x20Busquets\x22,\x22lastAction\x22\x3A\x22BallRecovery\x22\x7D,\x7B\x22id\x22\x3A\x2232529\x22,\x22minute\x22\x3A\x2262\x22,\x22result\x22\x3A\x22Goal\x22,\x22X\x22\x3A\x220.86\x22,\x22Y\x22\x3A\x220.435\x22,\x22xG\x22\x3A\x220.15034300088882446\x22,\x22player\x22\x3A\x22Lionel\x20Messi\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x222097\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222014\x22,\x22shotType\x22\x3A\x22LeftFoot\x22,\x22match_id\x22\x3A\x225831\x22,\x22h_team\x22\x3A\x22Barcelona\x22,\x22a_team\x22\x3A\x22Elche\x22,\x22h_goals\x22\x3A\x223\x22,\x22a_goals\x22\x3A\x220\x22,\x22date\x22\x3A\x222014\x2D08\x2D24\x2020\x3A00\x3A00\x22,\x22player_assisted\x22\x3Anull,\x22lastAction\x22\x3A\x22TakeOn\x22\x7D,\x7B\x22id\x22\x3A\x2232769\x22,\x22minute\x22\x3A\x223\x22,\x22result\x22\x3A\x22SavedShot\x22,\x22X\x22\x3A\x220.8180000305175781\x22,\x22Y\x22\x3A\x220.38\x22,\x22xG\x22\x3A\x220.04550329968333244\x22,\x22player\x22\x3A\x22Lionel\x20Messi\x22,\x22h_a\x22\x3A\x22a\x22,\x22player_id\x22\x3A\x222097\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222014\x22,\x22shotType\x22\x3A\x22LeftFoot\x22,\x22match_id\x22\x3A\x225842\x22,\x22h_team\x22\x3A\x22Villarreal\x22,\x22a_team\x22\x3A\x22Barcelona\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x221\x22,\x22date\x22\x3A\x222014\x2D08\x2D31\x2018\x3A00\x3A00\x22,\x22player_assisted\x22\x3A\x22Pedro\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x2232773\x22,\x22minute\x22\x3A\x2227\x22,\x22result\x22\x3A\x22SavedShot\x22,\x22X\x22\x3A\x220.8690000152587891\x22,\x22Y\x22\x3A\x220.19200000762939454\x22,\x22xG\x22\x3A\x220.06531669944524765\x22,\x22player\x22\x3A\x22Lionel\x20Messi\x22,\x22h_a\x22\x3A\x22a\x22,\x22player_id\x22\x3A\x222097\x22,\x22situation\x22\x3A\x22DirectFreekick\x22,\x22season\x22\x3A\x222014\x22,\x22shotType\x22\x3A\x22LeftFoot\x22,\x22match_id\x22\x3A\x225842\x22,\x22h_team\x22\x3A\x22Villarreal\x22,\x22a_team\x22\x3A\x22Barcelona\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x221\x22,\x22date\x22\x3A\x222014\x2D08\x2D31\x2018\x3A00\x3A00\x22,\x22player_assisted\x22\x3Anull,\x22lastAction\x22\x3A\x22Standard\x22\x7D,\x7B\x22id\x22\x3A\x2232779\x22,\x22minute\x22\x3A\x2265\x22,\x22result\x22\x3A\x22SavedShot\x22,\x22X\x22\x3A\x220.7230000305175781\x22,\x22Y\x22\x3A\x220.49400001525878906\x22,\x22xG\x22\x3A\x220.05480489879846573\x22,\x22player\x22\x3A\x22Lionel\x20Messi\x22,\x22h_a\x22\x3A\x22a\x22,\x22player_id\x22\x3A\x222097\x22,\x22situation\x22\x3A\x22DirectFreekick\x22,\x22season\x22\x3A\x222014\x2 ...
#  		player_info	= JSON.parse('\x7B\x22id\x22\x3A\x222097\x22,\x22name\x22\x3A\x22Lionel\x20Messi\x22,\x22fid\x22\x3A\x2211119\x22\x7D');
#  </script>,
#  <script>
#  	var matchesData	= JSON.parse('\x5B\x7B\x22goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x226\x22,\x22xG\x22\x3A\x220.6566415429115295\x22,\x22time\x22\x3A\x2290\x22,\x22position\x22\x3A\x22AMC\x22,\x22h_team\x22\x3A\x22Paris\x20Saint\x20Germain\x22,\x22a_team\x22\x3A\x22Clermont\x20Foot\x22,\x22h_goals\x22\x3A\x222\x22,\x22a_goals\x22\x3A\x223\x22,\x22date\x22\x3A\x222023\x2D06\x2D03\x22,\x22id\x22\x3A\x2220024\x22,\x22season\x22\x3A\x222022\x22,\x22roster_id\x22\x3A\x22602052\x22,\x22xA\x22\x3A\x220.47902199625968933\x22,\x22assists\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x224\x22,\x22npg\x22\x3A\x220\x22,\x22npxG\x22\x3A\x220.6566415429115295\x22,\x22xGChain\x22\x3A\x221.1349878311157227\x22,\x22xGBuildup\x22\x3A\x220.18565507233142853\x22\x7D,\x7B\x22goals\x22\x3A\x221\x22,\x22shots\x22\x3A\x223\x22,\x22xG\x22\x3A\x220.2420475333929062\x22,\x22time\x22\x3A\x2290\x22,\x22position\x22\x3A\x22FW\x22,\x22h_team\x22\x3A\x22Strasbourg\x22,\x22a_team\x22\x3A\x22Paris\x20Saint\x20Germain\x22,\x22h_goals\x22\x3A\x221\x22,\x22a_goals\x22\x3A\x221\x22,\x22date\x22\x3A\x222023\x2D05\x2D27\x22,\x22id\x22\x3A\x2220015\x22,\x22season\x22\x3A\x222022\x22,\x22roster_id\x22\x3A\x22600532\x22,\x22xA\x22\x3A\x220.8832126259803772\x22,\x22assists\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x223\x22,\x22npg\x22\x3A\x221\x22,\x22npxG\x22\x3A\x220.2420475333929062\x22,\x22xGChain\x22\x3A\x220.7659698128700256\x22,\x22xGBuildup\x22\x3A\x220.10987631976604462\x22\x7D,\x7B\x22goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x224\x22,\x22xG\x22\x3A\x220.39585015177726746\x22,\x22time\x22\x3A\x2290\x22,\x22position\x22\x3A\x22FWR\x22,\x22h_team\x22\x3A\x22Auxerre\x22,\x22a_team\x22\x3A\x22Paris\x20Saint\x20Germain\x22,\x22h_goals\x22\x3A\x221\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222023\x2D05\x2D21\x22,\x22id\x22\x3A\x2219999\x22,\x22season\x22\x3A\x222022\x22,\x22roster_id\x22\x3A\x22599236\x22,\x22xA\x22\x3A\x220.459868848323822\x22,\x22assists\x22\x3A\x221\x22,\x22key_passes\x22\x3A\x225\x22,\x22npg\x22\x3A\x220\x22,\x22npxG\x22\x3A\x220.39585015177726746\x22,\x22xGChain\x22\x3A\x221.530362844467163\x22,\x22xGBuildup\x22\x3A\x220.9853394031524658\x22\x7D,\x7B\x22goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x223\x22,\x22xG\x22\x3A\x220.24880366027355194\x22,\x22time\x22\x3A\x2290\x22,\x22position\x22\x3A\x22FWR\x22,\x22h_team\x22\x3A\x22Paris\x20Saint\x20Germain\x22,\x22a_team\x22\x3A\x22Ajaccio\x22,\x22h_goals\x22\x3A\x225\x22,\x22a_goals\x22\x3A\x220\x22,\x22date\x22\x3A\x222023\x2D05\x2D13\x22,\x22id\x22\x3A\x2219992\x22,\x22season\x22\x3A\x222022\x22,\x22roster_id\x22\x3A\x22596712\x22,\x22xA\x22\x3A\x220.16158834099769592\x22,\x22assists\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x222\x22,\x22npg\x22\x3A\x220\x22,\x22npxG\x22\x3A\x220.24880366027355194\x22,\x22xGChain\x22\x3A\x220.5141270756721497\x22,\x22xGBuildup\x22\x3A\x220.4185616075992584\x22\x7D,\x7B\x22goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x221\x22,\x22xG\x22\x3A\x220.01167652104049921\x22,\x22time\x22\x3A\x2290\x22,\x22position\x22\x3A\x22FW\x22,\x22h_team\x22\x3A\x22Paris\x20Saint\x20Germain\x22,\x22a_team\x22\x3A\x22Lorient\x22,\x22h_goals\x22\x3A\x221\x22,\x22a_goals\x22\x3A\x223\x22,\x22date\x22\x3A\x222023\x2D04\x2D30\x22,\x22id\x22\x3A\x2219972\x22,\x22season\x22\x3A\x222022\x22,\x22roster_id\x22\x3A\x22593232\x22,\x22xA\x22\x3A\x220.2014019638299942\x22,\x22assists\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x222\x22,\x22npg\x22\x3A\x220\x22,\x22npxG\x22\x3A\x220.01167652104049921\x22,\x22xGChain\x22\x3A\x220.01167652104049921\x22,\x22xGBuildup\x22\x3A\x220\x22\x7D,\x7B\x22goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x222\x22,\x22xG\x22\x3A\x220.16383212804794312\x22,\x22time\x22\x3A\x2290\x22,\x22position\x22\x3A\x22FW\x22,\x22h_team\x22\x3A\x22Angers\x22,\x22a_team\x22\x3A\x22Paris\x20Saint\x20Germain\x22,\x22h_goals\x22\x3A\x221\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222023\x2D04\x2D21\x22,\x22id\x22\x3A\x2219960\x22,\x22season\x22\x3A\x222022\x22,\x22roster_id\x22\x3A\x22589729 ...
#  </script>,
#  <script defer="" src="//ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js" type="text/javascript"></script>,
#  <script src="//ajax.googleapis.com/ajax/libs/webfont/1.6.26/webfont.js" type="text/javascript"></script>,
#  <script>
#  		WebFont.load({
#  			google: {
#  				families: ['Barlow:500', 'Anton']
#  			},
#  			active: function(){
#  				flagFontsLoading = true;
#  			}
#  		});
#  		var BASE_URL = 'https://understat.com/',
#  			PROMOTION =  JSON.parse('\x7B\x22id\x22\x3A\x227\x22,\x22name\x22\x3A\x22adsense\x22,\x22template\x22\x3A\x22\x3Cins\x20class\x3D\x5C\x22adsbygoogle\x5C\x22\x20style\x3D\x5C\x22display\x3Ablock\x5C\x22\x20data\x2Dad\x2Dclient\x3D\x5C\x22ca\x2Dpub\x2D7470116180195095\x5C\x22\x20data\x2Dad\x2Dslot\x3D\x5C\x222199699885\x5C\x22\x20data\x2Dad\x2Dformat\x3D\x5C\x22auto\x5C\x22\x20data\x2Dfull\x2Dwidth\x2Dresponsive\x3D\x5C\x22true\x5C\x22\x3E\x3C\x5C\x2Fins\x3E\x22,\x22js\x22\x3A\x22\x28adsbygoogle\x20\x3D\x20window.adsbygoogle\x20\x7C\x7C\x20\x5B\x5D\x29.push\x28\x7B\x7D\x29\x3B\x22,\x22countries_list_type\x22\x3A\x22black\x22,\x22clicks\x22\x3A\x224063\x22\x7D') ;
#  	</script>,
#  <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>,
#  <script defer="" src="//code.jquery.com/jquery-1.12.4.js" type="text/javascript"></script>,
#  <script defer="" src="//code.jquery.com/ui/1.12.1/jquery-ui.js" type="text/javascript"></script>,
#  <script defer="" src="js/jquery.iframetracker.min.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="//cdnjs.cloudflare.com/ajax/libs/Chart.js/2.7.2/Chart.min.js" type="text/javascript"></script>,
#  <script defer="" src="js/timsort.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/tooltip.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/pagination.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/select.js?v=2.1" type="text/javascript"></script>,
#  <script defer="" src="js/jquery.mousewheel.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/modernizr.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/simplebar.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/typeahead.bundle.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/jTable.js?v=2.6" type="text/javascript"></script>,
#  <script defer="" src="js/main.js?v=2.9" type="text/javascript"></script>,
#  <script>
#  		(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#  		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#  		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#  		})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#  		ga('create', 'UA-101482034-1', 'auto');
#  		ga('send', 'pageview');
#
#  					window.onload = function() { (adsbygoogle = window.adsbygoogle || []).push({}); }
#  			</script>,
#  <script defer="" src="js/player.js?v=2.5" type="text/javascript"></script>]

# %%
#get only shots data from scripts, 4th string ([3]) 

strings = scripts[3].string

# %%
strings
# Out:
# "\n\tvar shotsData \t= JSON.parse('\\x5B\\x7B\\x22id\\x22\\x3A\\x2232522\\x22,\\x22minute\\x22\\x3A\\x2222\\x22,\\x22result\\x22\\x3A\\x22MissedShots\\x22,\\x22X\\x22\\x3A\\x220.7859999847412109\\x22,\\x22Y\\x22\\x3A\\x220.52\\x22,\\x22xG\\x22\\x3A\\x220.03867039829492569\\x22,\\x22player\\x22\\x3A\\x22Lionel\\x20Messi\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x222097\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222014\\x22,\\x22shotType\\x22\\x3A\\x22LeftFoot\\x22,\\x22match_id\\x22\\x3A\\x225831\\x22,\\x22h_team\\x22\\x3A\\x22Barcelona\\x22,\\x22a_team\\x22\\x3A\\x22Elche\\x22,\\x22h_goals\\x22\\x3A\\x223\\x22,\\x22a_goals\\x22\\x3A\\x220\\x22,\\x22date\\x22\\x3A\\x222014\\x2D08\\x2D24\\x2020\\x3A00\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Rafinha\\x22,\\x22lastAction\\x22\\x3A\\x22Pass\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x2232525\\x22,\\x22minute\\x22\\x3A\\x2241\\x22,\\x22result\\x22\\x3A\\x22Goal\\x22,\\x22X\\x22\\x3A\\x220.8619999694824219\\x22,\\x22Y\\x22\\x3A\\x220.615\\x22,\\x22xG\\x22\\x3A\\x220.06870149821043015\\x22,\\x22player\\x22\\x3A\\x22Lionel\\x20Messi\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x222097\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222014\\x22,\\x22shotType\\x22\\x3A\\x22LeftFoot\\x22,\\x22match_id\\x22\\x3A\\x225831\\x22,\\x22h_team\\x22\\x3A\\x22Barcelona\\x22,\\x22a_team\\x22\\x3A\\x22Elche\\x22,\\x22h_goals\\x22\\x3A\\x223\\x22,\\x22a_goals\\x22\\x3A\\x220\\x22,\\x22date\\x22\\x3A\\x222014\\x2D08\\x2D24\\x2020\\x3A00\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Sergio\\x20Busquets\\x22,\\x22lastAction\\x22\\x3A\\x22BallRecovery\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x2232529\\x22,\\x22minute\\x22\\x3A\\x2262\\x22,\\x22result\\x22\\x3A\\x22Goal\\x22,\\x22X\\x22\\x3A\\x220.86\\x22,\\x22Y\\x22\\x3A\\x220.435\\x22,\\x22xG\\x22\\x3A\\x220.15034300088882446\\x22,\\x22player\\x22\\x3A\\x22Lionel\\x20Messi\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x222097\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222014\\x22,\\x22shotType\\x22\\x3A\\x22LeftFoot\\x22,\\x22match_id\\x22\\x3A\\x225831\\x22,\\x22h_team\\x22\\x3A\\x22Barcelona\\x22,\\x22a_team\\x22\\x3A\\x22Elche\\x22,\\x22h_goals\\x22\\x3A\\x223\\x22,\\x22a_goals\\x22\\x3A\\x220\\x22,\\x22date\\x22\\x3A\\x222014\\x2D08\\x2D24\\x2020\\x3A00\\x3A00\\x22,\\x22player_assisted\\x22\\x3Anull,\\x22lastAction\\x22\\x3A\\x22TakeOn\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x2232769\\x22,\\x22minute\\x22\\x3A\\x223\\x22,\\x22result\\x22\\x3A\\x22SavedShot\\x22,\\x22X\\x22\\x3A\\x220.8180000305175781\\x22,\\x22Y\\x22\\x3A\\x220.38\\x22,\\x22xG\\x22\\x3A\\x220.04550329968333244\\x22,\\x22player\\x22\\x3A\\x22Lionel\\x20Messi\\x22,\\x22h_a\\x22\\x3A\\x22a\\x22,\\x22player_id\\x22\\x3A\\x222097\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222014\\x22,\\x22shotType\\x22\\x3A\\x22LeftFoot\\x22,\\x22match_id\\x22\\x3A\\x225842\\x22,\\x22h_team\\x22\\x3A\\x22Villarreal\\x22,\\x22a_team\\x22\\x3A\\x22Barcelona\\x22,\\x22h_goals\\x22\\x3A\\x220\\x22,\\x22a_goals\\x22\\x3A\\x221\\x22,\\x22date\\x22\\x3A\\x222014\\x2D08\\x2D31\\x2018\\x3A00\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Pedro\\x22,\\x22lastAction\\x22\\x3A\\x22Pass\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x2232773\\x22,\\x22minute\\x22\\x3A\\x2227\\x22,\\x22result\\x22\\x3A\\x22SavedShot\\x22,\\x22X\\x22\\x3A\\x220.8690000152587891\\x22,\\x22Y\\x22\\x3A\\x220.19200000762939454\\x22,\\x22xG\\x22\\x3A\\x220.06531669944524765\\x22,\\x22player\\x22\\x3A\\x22Lionel\\x20Messi\\x22,\\x22h_a\\x22\\x3A\\x22a\\x22,\\x22player_id\\x22\\x3A\\x222097\\x22,\\x22situation\\x22\\x3A\\x22DirectFreekick\\x22,\\x22season\\x22\\x3A\\x222014\\x22,\\x22shotType\\x22\\x3A\\x22LeftFoot\\x22,\\x22match_id\\x22\\x3A\\x225842\\x22,\\x22h_team\\x22\\x3A\\x22Villarreal\\x22,\\x22a_team\\x22\\x3A\\x22Barcelona\\x22,\\x22h_goals\\x22\\x3A\\x220\\x22,\\x22a_goals\\x22\\x3A\\x221\\x22,\\x22 ...

# %%
#strip symbols, make json

ind_start = strings.index("('")+2
ind_end = strings.index("')")

json_data = strings[ind_start:ind_end]
json_data = json_data.encode('utf8)').decode('unicode_escape')

data = json.loads(json_data)

# %%
data
# Out:
# [{'id': '32522',
#   'minute': '22',
#   'result': 'MissedShots',
#   'X': '0.7859999847412109',
#   'Y': '0.52',
#   'xG': '0.03867039829492569',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5831',
#   'h_team': 'Barcelona',
#   'a_team': 'Elche',
#   'h_goals': '3',
#   'a_goals': '0',
#   'date': '2014-08-24 20:00:00',
#   'player_assisted': 'Rafinha',
#   'lastAction': 'Pass'},
#  {'id': '32525',
#   'minute': '41',
#   'result': 'Goal',
#   'X': '0.8619999694824219',
#   'Y': '0.615',
#   'xG': '0.06870149821043015',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5831',
#   'h_team': 'Barcelona',
#   'a_team': 'Elche',
#   'h_goals': '3',
#   'a_goals': '0',
#   'date': '2014-08-24 20:00:00',
#   'player_assisted': 'Sergio Busquets',
#   'lastAction': 'BallRecovery'},
#  {'id': '32529',
#   'minute': '62',
#   'result': 'Goal',
#   'X': '0.86',
#   'Y': '0.435',
#   'xG': '0.15034300088882446',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5831',
#   'h_team': 'Barcelona',
#   'a_team': 'Elche',
#   'h_goals': '3',
#   'a_goals': '0',
#   'date': '2014-08-24 20:00:00',
#   'player_assisted': None,
#   'lastAction': 'TakeOn'},
#  {'id': '32769',
#   'minute': '3',
#   'result': 'SavedShot',
#   'X': '0.8180000305175781',
#   'Y': '0.38',
#   'xG': '0.04550329968333244',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5842',
#   'h_team': 'Villarreal',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2014-08-31 18:00:00',
#   'player_assisted': 'Pedro',
#   'lastAction': 'Pass'},
#  {'id': '32773',
#   'minute': '27',
#   'result': 'SavedShot',
#   'X': '0.8690000152587891',
#   'Y': '0.19200000762939454',
#   'xG': '0.06531669944524765',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'DirectFreekick',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5842',
#   'h_team': 'Villarreal',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2014-08-31 18:00:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '32779',
#   'minute': '65',
#   'result': 'SavedShot',
#   'X': '0.7230000305175781',
#   'Y': '0.49400001525878906',
#   'xG': '0.05480489879846573',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'DirectFreekick',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5842',
#   'h_team': 'Villarreal',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2014-08-31 18:00:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '32780',
#   'minute': '66',
#   'result': 'MissedShots',
#   'X': '0.9119999694824219',
#   'Y': '0.49900001525878906',
#   'xG': '0.0971859022974968',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'FromCorner',
#   'season': '2014',
#   'shotType': 'Head',
#   'match_id': '5842',
#   'h_team': 'Villarreal',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2014-08-31 18:00:00',
#   'player_assisted': 'Ivan Rakitic',
#   'lastAction': 'Cross'},
#  {'id': '32787',
#   'minute': '71',
#   'result': 'BlockedShot',
#   'X': '0.885',
#   'Y': '0.6020000076293945',
#   'xG': '0.1146790012717247',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5842',
#   'h_team': 'Villarreal',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2014-08-31 18:00:00',
#   'player_assisted': 'Rafinha',
#   'lastAction': 'Pass'},
#  {'id': '32788',
#   'minute': '76',
#   'result': 'BlockedShot',
#   'X': '0.875999984741211',
#   'Y': '0.43900001525878907',
#   'xG': '0.10627499967813492',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'RightFoot',
#   'match_id': '5842',
#   'h_team': 'Villarreal',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2014-08-31 18:00:00',
#   'player_assisted': 'Dani Alves',
#   'lastAction': 'Pass'},
#  {'id': '32790',
#   'minute': '81',
#   'result': 'SavedShot',
#   'X': '0.9540000152587891',
#   'Y': '0.33599998474121096',
#   'xG': '0.31001999974250793',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5842',
#   'h_team': 'Villarreal',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2014-08-31 18:00:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '32789',
#   'minute': '81',
#   'result': 'BlockedShot',
#   'X': '0.8969999694824219',
#   'Y': '0.4470000076293945',
#   'xG': '0.12571699917316437',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5842',
#   'h_team': 'Villarreal',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2014-08-31 18:00:00',
#   'player_assisted': 'Neymar',
#   'lastAction': 'Pass'},
#  {'id': '33012',
#   'minute': '36',
#   'result': 'MissedShots',
#   'X': '0.8959999847412109',
#   'Y': '0.5320000076293945',
#   'xG': '0.04122979938983917',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'Head',
#   'match_id': '5787',
#   'h_team': 'Barcelona',
#   'a_team': 'Athletic Club',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2014-09-13 15:00:00',
#   'player_assisted': 'Ivan Rakitic',
#   'lastAction': 'Aerial'},
#  {'id': '33013',
#   'minute': '40',
#   'result': 'BlockedShot',
#   'X': '0.8730000305175781',
#   'Y': '0.565',
#   'xG': '0.0994253009557724',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5787',
#   'h_team': 'Barcelona',
#   'a_team': 'Athletic Club',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2014-09-13 15:00:00',
#   'player_assisted': 'Munir',
#   'lastAction': 'Pass'},
#  {'id': '33697',
#   'minute': '22',
#   'result': 'BlockedShot',
#   'X': '0.769000015258789',
#   'Y': '0.5709999847412109',
#   'xG': '0.025321800261735916',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5804',
#   'h_team': 'Levante',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '5',
#   'date': '2014-09-21 20:00:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '33703',
#   'minute': '41',
#   'result': 'MissedShots',
#   'X': '0.885',
#   'Y': '0.5',
#   'xG': '0.7432780265808105',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'Penalty',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5804',
#   'h_team': 'Levante',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '5',
#   'date': '2014-09-21 20:00:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '33714',
#   'minute': '76',
#   'result': 'Goal',
#   'X': '0.86',
#   'Y': '0.48700000762939455',
#   'xG': '0.4680370092391968',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'RightFoot',
#   'match_id': '5804',
#   'h_team': 'Levante',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '5',
#   'date': '2014-09-21 20:00:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '33388',
#   'minute': '14',
#   'result': 'MissedShots',
#   'X': '0.7619999694824219',
#   'Y': '0.31',
#   'xG': '0.05699079856276512',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'DirectFreekick',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5813',
#   'h_team': 'Malaga',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '0',
#   'date': '2014-09-24 21:00:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '33391',
#   'minute': '25',
#   'result': 'MissedShots',
#   'X': '0.919000015258789',
#   'Y': '0.52',
#   'xG': '0.10647399723529816',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'OtherBodyPart',
#   'match_id': '5813',
#   'h_team': 'Malaga',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '0',
#   'date': '2014-09-24 21:00:00',
#   'player_assisted': 'Jordi Alba',
#   'lastAction': 'Cross'},
#  {'id': '35699',
#   'minute': '61',
#   'result': 'Goal',
#   'X': '0.9530000305175781',
#   'Y': '0.5379999923706055',
#   'xG': '0.5716009736061096',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'Head',
#   'match_id': '5818',
#   'h_team': 'Barcelona',
#   'a_team': 'Granada',
#   'h_goals': '6',
#   'a_goals': '0',
#   'date': '2014-09-27 17:00:00',
#   'player_assisted': 'Dani Alves',
#   'lastAction': 'Cross'},
#  {'id': '35702',
#   'minute': '77',
#   'result': 'SavedShot',
#   'X': '0.8280000305175781',
#   'Y': '0.3840000152587891',
#   'xG': '0.07561510056257248',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5818',
#   'h_team': 'Barcelona',
#   'a_team': 'Granada',
#   'h_goals': '6',
#   'a_goals': '0',
#   'date': '2014-09-27 17:00:00',
#   'player_assisted': 'Sergi Roberto',
#   'lastAction': 'Pass'},
#  {'id': '35705',
#   'minute': '81',
#   'result': 'Goal',
#   'X': '0.9030000305175782',
#   'Y': '0.4540000152587891',
#   'xG': '0.46004998683929443',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'RightFoot',
#   'match_id': '5818',
#   'h_team': 'Barcelona',
#   'a_team': 'Granada',
#   'h_goals': '6',
#   'a_goals': '0',
#   'date': '2014-09-27 17:00:00',
#   'player_assisted': None,
#   'lastAction': 'BallRecovery'},
#  {'id': '34578',
#   'minute': '13',
#   'result': 'SavedShot',
#   'X': '0.9469999694824218',
#   'Y': '0.4',
#   'xG': '0.3132370114326477',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'RightFoot',
#   'match_id': '5756',
#   'h_team': 'Rayo Vallecano',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '2',
#   'date': '2014-10-04 17:00:00',
#   'player_assisted': 'Neymar',
#   'lastAction': 'Chipped'},
#  {'id': '34580',
#   'minute': '34',
#   'result': 'Goal',
#   'X': '0.92',
#   'Y': '0.6270000076293946',
#   'xG': '0.28696998953819275',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5756',
#   'h_team': 'Rayo Vallecano',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '2',
#   'date': '2014-10-04 17:00:00',
#   'player_assisted': 'Gerard Piqué',
#   'lastAction': 'Chipped'},
#  {'id': '34589',
#   'minute': '60',
#   'result': 'MissedShots',
#   'X': '0.7659999847412109',
#   'Y': '0.6120000076293945',
#   'xG': '0.07576990127563477',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'DirectFreekick',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5756',
#   'h_team': 'Rayo Vallecano',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '2',
#   'date': '2014-10-04 17:00:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '34591',
#   'minute': '64',
#   'result': 'BlockedShot',
#   'X': '0.9640000152587891',
#   'Y': '0.39',
#   'xG': '0.3824149966239929',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'RightFoot',
#   'match_id': '5756',
#   'h_team': 'Rayo Vallecano',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '2',
#   'date': '2014-10-04 17:00:00',
#   'player_assisted': 'Jeremy Mathieu',
#   'lastAction': 'Pass'},
#  {'id': '34598',
#   'minute': '81',
#   'result': 'MissedShots',
#   'X': '0.8590000152587891',
#   'Y': '0.46599998474121096',
#   'xG': '0.12827999889850616',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5756',
#   'h_team': 'Rayo Vallecano',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '2',
#   'date': '2014-10-04 17:00:00',
#   'player_assisted': 'Xavi',
#   'lastAction': 'Pass'},
#  {'id': '34600',
#   'minute': '83',
#   'result': 'MissedShots',
#   'X': '0.9330000305175781',
#   'Y': '0.41',
#   'xG': '0.4291499853134155',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'RightFoot',
#   'match_id': '5756',
#   'h_team': 'Rayo Vallecano',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '2',
#   'date': '2014-10-04 17:00:00',
#   'player_assisted': 'Xavi',
#   'lastAction': 'Pass'},
#  {'id': '34605',
#   'minute': '89',
#   'result': 'BlockedShot',
#   'X': '0.8240000152587891',
#   'Y': '0.40200000762939453',
#   'xG': '0.08198580145835876',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5756',
#   'h_team': 'Rayo Vallecano',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '2',
#   'date': '2014-10-04 17:00:00',
#   'player_assisted': 'Sergio Busquets',
#   'lastAction': 'Pass'},
#  {'id': '34606',
#   'minute': '89',
#   'result': 'MissedShots',
#   'X': '0.9230000305175782',
#   'Y': '0.5670000076293945',
#   'xG': '0.49682000279426575',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5756',
#   'h_team': 'Rayo Vallecano',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '2',
#   'date': '2014-10-04 17:00:00',
#   'player_assisted': 'Gerard Piqué',
#   'lastAction': 'Pass'},
#  {'id': '35316',
#   'minute': '19',
#   'result': 'SavedShot',
#   'X': '0.965999984741211',
#   'Y': '0.40400001525878904',
#   'xG': '0.43097400665283203',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5767',
#   'h_team': 'Barcelona',
#   'a_team': 'Eibar',
#   'h_goals': '3',
#   'a_goals': '0',
#   'date': '2014-10-18 19:00:00',
#   'player_assisted': 'Dani Alves',
#   'lastAction': 'Throughball'},
#  {'id': '35317',
#   'minute': '24',
#   'result': 'MissedShots',
#   'X': '0.8490000152587891',
#   'Y': '0.539000015258789',
#   'xG': '0.07011710107326508',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5767',
#   'h_team': 'Barcelona',
#   'a_team': 'Eibar',
#   'h_goals': '3',
#   'a_goals': '0',
#   'date': '2014-10-18 19:00:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '35322',
#   'minute': '43',
#   'result': 'SavedShot',
#   'X': '0.8780000305175781',
#   'Y': '0.49900001525878906',
#   'xG': '0.05718180164694786',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'Head',
#   'match_id': '5767',
#   'h_team': 'Barcelona',
#   'a_team': 'Eibar',
#   'h_goals': '3',
#   'a_goals': '0',
#   'date': '2014-10-18 19:00:00',
#   'player_assisted': 'Pedro',
#   'lastAction': 'Cross'},
#  {'id': '35330',
#   'minute': '61',
#   'result': 'BlockedShot',
#   'X': '0.8819999694824219',
#   'Y': '0.5070000076293946',
#   'xG': '0.04670190066099167',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'FromCorner',
#   'season': '2014',
#   'shotType': 'Head',
#   'match_id': '5767',
#   'h_team': 'Barcelona',
#   'a_team': 'Eibar',
#   'h_goals': '3',
#   'a_goals': '0',
#   'date': '2014-10-18 19:00:00',
#   'player_assisted': 'Xavi',
#   'lastAction': 'Cross'},
#  {'id': '35332',
#   'minute': '66',
#   'result': 'SavedShot',
#   'X': '0.96',
#   'Y': '0.33799999237060546',
#   'xG': '0.05747399851679802',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'FromCorner',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5767',
#   'h_team': 'Barcelona',
#   'a_team': 'Eibar',
#   'h_goals': '3',
#   'a_goals': '0',
#   'date': '2014-10-18 19:00:00',
#   'player_assisted': None,
#   'lastAction': 'TakeOn'},
#  {'id': '35336',
#   'minute': '73',
#   'result': 'Goal',
#   'X': '0.899000015258789',
#   'Y': '0.664000015258789',
#   'xG': '0.10420800000429153',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5767',
#   'h_team': 'Barcelona',
#   'a_team': 'Eibar',
#   'h_goals': '3',
#   'a_goals': '0',
#   'date': '2014-10-18 19:00:00',
#   'player_assisted': 'Neymar',
#   'lastAction': 'Pass'},
#  {'id': '35341',
#   'minute': '88',
#   'result': 'SavedShot',
#   'X': '0.855',
#   'Y': '0.44299999237060544',
#   'xG': '0.0714716985821724',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5767',
#   'h_team': 'Barcelona',
#   'a_team': 'Eibar',
#   'h_goals': '3',
#   'a_goals': '0',
#   'date': '2014-10-18 19:00:00',
#   'player_assisted': 'Xavi',
#   'lastAction': 'TakeOn'},
#  {'id': '35343',
#   'minute': '92',
#   'result': 'SavedShot',
#   'X': '0.935',
#   'Y': '0.485',
#   'xG': '0.5211949944496155',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'Head',
#   'match_id': '5767',
#   'h_team': 'Barcelona',
#   'a_team': 'Eibar',
#   'h_goals': '3',
#   'a_goals': '0',
#   'date': '2014-10-18 19:00:00',
#   'player_assisted': 'Andrés Iniesta',
#   'lastAction': 'Throughball'},
#  {'id': '35886',
#   'minute': '21',
#   'result': 'SavedShot',
#   'X': '0.87',
#   'Y': '0.5770000076293945',
#   'xG': '0.10952100157737732',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5776',
#   'h_team': 'Real Madrid',
#   'a_team': 'Barcelona',
#   'h_goals': '3',
#   'a_goals': '1',
#   'date': '2014-10-25 17:00:00',
#   'player_assisted': 'Jeremy Mathieu',
#   'lastAction': 'Pass'},
#  {'id': '35887',
#   'minute': '22',
#   'result': 'SavedShot',
#   'X': '0.9330000305175781',
#   'Y': '0.5109999847412109',
#   'xG': '0.5061780214309692',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5776',
#   'h_team': 'Real Madrid',
#   'a_team': 'Barcelona',
#   'h_goals': '3',
#   'a_goals': '1',
#   'date': '2014-10-25 17:00:00',
#   'player_assisted': 'Luis Suárez',
#   'lastAction': 'Cross'},
#  {'id': '35897',
#   'minute': '46',
#   'result': 'BlockedShot',
#   'X': '0.7680000305175781',
#   'Y': '0.31799999237060544',
#   'xG': '0.06187250092625618',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'DirectFreekick',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5776',
#   'h_team': 'Real Madrid',
#   'a_team': 'Barcelona',
#   'h_goals': '3',
#   'a_goals': '1',
#   'date': '2014-10-25 17:00:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '35911',
#   'minute': '92',
#   'result': 'MissedShots',
#   'X': '0.75',
#   'Y': '0.5259999847412109',
#   'xG': '0.07309029996395111',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'DirectFreekick',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5776',
#   'h_team': 'Real Madrid',
#   'a_team': 'Barcelona',
#   'h_goals': '3',
#   'a_goals': '1',
#   'date': '2014-10-25 17:00:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '33949',
#   'minute': '29',
#   'result': 'SavedShot',
#   'X': '0.8690000152587891',
#   'Y': '0.58',
#   'xG': '0.10076600313186646',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5718',
#   'h_team': 'Barcelona',
#   'a_team': 'Celta Vigo',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2014-11-01 19:00:00',
#   'player_assisted': 'Neymar',
#   'lastAction': 'Pass'},
#  {'id': '33950',
#   'minute': '31',
#   'result': 'BlockedShot',
#   'X': '0.9030000305175782',
#   'Y': '0.6070000076293945',
#   'xG': '0.38531699776649475',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5718',
#   'h_team': 'Barcelona',
#   'a_team': 'Celta Vigo',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2014-11-01 19:00:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '33951',
#   'minute': '33',
#   'result': 'MissedShots',
#   'X': '0.909000015258789',
#   'Y': '0.46700000762939453',
#   'xG': '0.28372499346733093',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'Head',
#   'match_id': '5718',
#   'h_team': 'Barcelona',
#   'a_team': 'Celta Vigo',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2014-11-01 19:00:00',
#   'player_assisted': 'Luis Suárez',
#   'lastAction': 'Cross'},
#  {'id': '33960',
#   'minute': '64',
#   'result': 'SavedShot',
#   'X': '0.9440000152587891',
#   'Y': '0.675',
#   'xG': '0.08025799691677094',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5718',
#   'h_team': 'Barcelona',
#   'a_team': 'Celta Vigo',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2014-11-01 19:00:00',
#   'player_assisted': None,
#   'lastAction': 'TakeOn'},
#  {'id': '33964',
#   'minute': '73',
#   'result': 'MissedShots',
#   'X': '0.8009999847412109',
#   'Y': '0.5379999923706055',
#   'xG': '0.13314299285411835',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'DirectFreekick',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5718',
#   'h_team': 'Barcelona',
#   'a_team': 'Celta Vigo',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2014-11-01 19:00:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '33967',
#   'minute': '79',
#   'result': 'ShotOnPost',
#   'X': '0.7319999694824219',
#   'Y': '0.4620000076293945',
#   'xG': '0.05950070172548294',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'DirectFreekick',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5718',
#   'h_team': 'Barcelona',
#   'a_team': 'Celta Vigo',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2014-11-01 19:00:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '34634',
#   'minute': '8',
#   'result': 'SavedShot',
#   'X': '0.924000015258789',
#   'Y': '0.4129999923706055',
#   'xG': '0.11834999918937683',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5726',
#   'h_team': 'Almeria',
#   'a_team': 'Barcelona',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2014-11-08 15:00:00',
#   'player_assisted': None,
#   'lastAction': 'Rebound'},
#  {'id': '34633',
#   'minute': '8',
#   'result': 'SavedShot',
#   'X': '0.9519999694824218',
#   'Y': '0.41700000762939454',
#   'xG': '0.08737509697675705',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5726',
#   'h_team': 'Almeria',
#   'a_team': 'Barcelona',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2014-11-08 15:00:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '34642',
#   'minute': '27',
#   'result': 'ShotOnPost',
#   'X': '0.9640000152587891',
#   'Y': '0.4909999847412109',
#   'xG': '0.6340219974517822',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'Head',
#   'match_id': '5726',
#   'h_team': 'Almeria',
#   'a_team': 'Barcelona',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2014-11-08 15:00:00',
#   'player_assisted': 'Pedro',
#   'lastAction': 'Rebound'},
#  {'id': '34652',
#   'minute': '78',
#   'result': 'ShotOnPost',
#   'X': '0.8730000305175781',
#   'Y': '0.40200000762939453',
#   'xG': '0.027184799313545227',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'Head',
#   'match_id': '5726',
#   'h_team': 'Almeria',
#   'a_team': 'Barcelona',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2014-11-08 15:00:00',
#   'player_assisted': 'Luis Suárez',
#   'lastAction': 'Pass'},
#  {'id': '34654',
#   'minute': '83',
#   'result': 'BlockedShot',
#   'X': '0.9159999847412109',
#   'Y': '0.29600000381469727',
#   'xG': '0.07396689802408218',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'RightFoot',
#   'match_id': '5726',
#   'h_team': 'Almeria',
#   'a_team': 'Barcelona',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2014-11-08 15:00:00',
#   'player_assisted': 'Ivan Rakitic',
#   'lastAction': 'BallRecovery'},
#  {'id': '34656',
#   'minute': '92',
#   'result': 'SavedShot',
#   'X': '0.875',
#   'Y': '0.46599998474121096',
#   'xG': '0.3958190083503723',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'RightFoot',
#   'match_id': '5726',
#   'h_team': 'Almeria',
#   'a_team': 'Barcelona',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2014-11-08 15:00:00',
#   'player_assisted': 'Luis Suárez',
#   'lastAction': 'Pass'},
#  {'id': '35373',
#   'minute': '7',
#   'result': 'SavedShot',
#   'X': '0.825',
#   'Y': '0.5609999847412109',
#   'xG': '0.05614989995956421',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5738',
#   'h_team': 'Barcelona',
#   'a_team': 'Sevilla',
#   'h_goals': '5',
#   'a_goals': '1',
#   'date': '2014-11-22 19:00:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '35375',
#   'minute': '20',
#   'result': 'Goal',
#   'X': '0.779000015258789',
#   'Y': '0.534000015258789',
#   'xG': '0.10196299850940704',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'DirectFreekick',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5738',
#   'h_team': 'Barcelona',
#   'a_team': 'Sevilla',
#   'h_goals': '5',
#   'a_goals': '1',
#   'date': '2014-11-22 19:00:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '35386',
#   'minute': '71',
#   'result': 'Goal',
#   'X': '0.9769999694824218',
#   'Y': '0.4620000076293945',
#   'xG': '0.9710699915885925',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'RightFoot',
#   'match_id': '5738',
#   'h_team': 'Barcelona',
#   'a_team': 'Sevilla',
#   'h_goals': '5',
#   'a_goals': '1',
#   'date': '2014-11-22 19:00:00',
#   'player_assisted': 'Neymar',
#   'lastAction': 'Pass'},
#  {'id': '35387',
#   'minute': '77',
#   'result': 'Goal',
#   'X': '0.8430000305175781',
#   'Y': '0.5420000076293945',
#   'xG': '0.12027499824762344',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5738',
#   'h_team': 'Barcelona',
#   'a_team': 'Sevilla',
#   'h_goals': '5',
#   'a_goals': '1',
#   'date': '2014-11-22 19:00:00',
#   'player_assisted': 'Neymar',
#   'lastAction': 'LayOff'},
#  {'id': '35390',
#   'minute': '88',
#   'result': 'SavedShot',
#   'X': '0.8780000305175781',
#   'Y': '0.6409999847412109',
#   'xG': '0.08988840132951736',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5738',
#   'h_team': 'Barcelona',
#   'a_team': 'Sevilla',
#   'h_goals': '5',
#   'a_goals': '1',
#   'date': '2014-11-22 19:00:00',
#   'player_assisted': 'Neymar',
#   'lastAction': 'Pass'},
#  {'id': '33522',
#   'minute': '79',
#   'result': 'BlockedShot',
#   'X': '0.7319999694824219',
#   'Y': '0.539000015258789',
#   'xG': '0.05945520102977753',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'DirectFreekick',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5753',
#   'h_team': 'Valencia',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2014-11-30 20:00:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '33523',
#   'minute': '91',
#   'result': 'BlockedShot',
#   'X': '0.9119999694824219',
#   'Y': '0.66',
#   'xG': '0.06372290104627609',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5753',
#   'h_team': 'Valencia',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2014-11-30 20:00:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '34248',
#   'minute': '29',
#   'result': 'ShotOnPost',
#   'X': '0.769000015258789',
#   'Y': '0.49',
#   'xG': '0.09176860004663467',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'DirectFreekick',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5692',
#   'h_team': 'Barcelona',
#   'a_team': 'Espanyol',
#   'h_goals': '5',
#   'a_goals': '1',
#   'date': '2014-12-07 16:00:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '34250',
#   'minute': '32',
#   'result': 'BlockedShot',
#   'X': '0.9290000152587891',
#   'Y': '0.32',
#   'xG': '0.07308740168809891',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'RightFoot',
#   'match_id': '5692',
#   'h_team': 'Barcelona',
#   'a_team': 'Espanyol',
#   'h_goals': '5',
#   'a_goals': '1',
#   'date': '2014-12-07 16:00:00',
#   'player_assisted': 'Xavi',
#   'lastAction': 'TakeOn'},
#  {'id': '34253',
#   'minute': '45',
#   'result': 'Goal',
#   'X': '0.794000015258789',
#   'Y': '0.5829999923706055',
#   'xG': '0.03690370172262192',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5692',
#   'h_team': 'Barcelona',
#   'a_team': 'Espanyol',
#   'h_goals': '5',
#   'a_goals': '1',
#   'date': '2014-12-07 16:00:00',
#   'player_assisted': 'Xavi',
#   'lastAction': 'Pass'},
#  {'id': '34254',
#   'minute': '49',
#   'result': 'Goal',
#   'X': '0.8419999694824218',
#   'Y': '0.500999984741211',
#   'xG': '0.0773795023560524',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'RightFoot',
#   'match_id': '5692',
#   'h_team': 'Barcelona',
#   'a_team': 'Espanyol',
#   'h_goals': '5',
#   'a_goals': '1',
#   'date': '2014-12-07 16:00:00',
#   'player_assisted': 'Luis Suárez',
#   'lastAction': 'TakeOn'},
#  {'id': '34257',
#   'minute': '69',
#   'result': 'MissedShots',
#   'X': '0.745999984741211',
#   'Y': '0.5629999923706055',
#   'xG': '0.0674016997218132',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'DirectFreekick',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5692',
#   'h_team': 'Barcelona',
#   'a_team': 'Espanyol',
#   'h_goals': '5',
#   'a_goals': '1',
#   'date': '2014-12-07 16:00:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '34261',
#   'minute': '80',
#   'result': 'Goal',
#   'X': '0.895',
#   'Y': '0.445',
#   'xG': '0.5030360221862793',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'RightFoot',
#   'match_id': '5692',
#   'h_team': 'Barcelona',
#   'a_team': 'Espanyol',
#   'h_goals': '5',
#   'a_goals': '1',
#   'date': '2014-12-07 16:00:00',
#   'player_assisted': 'Pedro',
#   'lastAction': 'Pass'},
#  {'id': '34902',
#   'minute': '17',
#   'result': 'SavedShot',
#   'X': '0.9019999694824219',
#   'Y': '0.4640000152587891',
#   'xG': '0.16307400166988373',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5698',
#   'h_team': 'Getafe',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '0',
#   'date': '2014-12-13 15:00:00',
#   'player_assisted': None,
#   'lastAction': 'TakeOn'},
#  {'id': '34912',
#   'minute': '51',
#   'result': 'ShotOnPost',
#   'X': '0.764000015258789',
#   'Y': '0.495',
#   'xG': '0.08656749874353409',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'DirectFreekick',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5698',
#   'h_team': 'Getafe',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '0',
#   'date': '2014-12-13 15:00:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '34913',
#   'minute': '52',
#   'result': 'BlockedShot',
#   'X': '0.779000015258789',
#   'Y': '0.48700000762939455',
#   'xG': '0.03668290004134178',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5698',
#   'h_team': 'Getafe',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '0',
#   'date': '2014-12-13 15:00:00',
#   'player_assisted': 'Luis Suárez',
#   'lastAction': 'Pass'},
#  {'id': '34915',
#   'minute': '57',
#   'result': 'SavedShot',
#   'X': '0.7819999694824219',
#   'Y': '0.20399999618530273',
#   'xG': '0.04316199943423271',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'DirectFreekick',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5698',
#   'h_team': 'Getafe',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '0',
#   'date': '2014-12-13 15:00:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '34919',
#   'minute': '68',
#   'result': 'MissedShots',
#   'X': '0.8959999847412109',
#   'Y': '0.534000015258789',
#   'xG': '0.08156900107860565',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'Head',
#   'match_id': '5698',
#   'h_team': 'Getafe',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '0',
#   'date': '2014-12-13 15:00:00',
#   'player_assisted': 'Jordi Alba',
#   'lastAction': 'Cross'},
#  {'id': '34924',
#   'minute': '81',
#   'result': 'BlockedShot',
#   'X': '0.8119999694824219',
#   'Y': '0.5029999923706054',
#   'xG': '0.05284259840846062',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5698',
#   'h_team': 'Getafe',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '0',
#   'date': '2014-12-13 15:00:00',
#   'player_assisted': 'Andrés Iniesta',
#   'lastAction': 'Pass'},
#  {'id': '34925',
#   'minute': '82',
#   'result': 'BlockedShot',
#   'X': '0.855',
#   'Y': '0.48',
#   'xG': '0.07320000231266022',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'RightFoot',
#   'match_id': '5698',
#   'h_team': 'Getafe',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '0',
#   'date': '2014-12-13 15:00:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '35633',
#   'minute': '36',
#   'result': 'BlockedShot',
#   'X': '0.8669999694824219',
#   'Y': '0.585',
#   'xG': '0.10526999831199646',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5708',
#   'h_team': 'Barcelona',
#   'a_team': 'Cordoba',
#   'h_goals': '5',
#   'a_goals': '0',
#   'date': '2014-12-20 15:00:00',
#   'player_assisted': 'Luis Suárez',
#   'lastAction': 'Pass'},
#  {'id': '35639',
#   'minute': '48',
#   'result': 'BlockedShot',
#   'X': '0.87',
#   'Y': '0.5979999923706054',
#   'xG': '0.09010829776525497',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5708',
#   'h_team': 'Barcelona',
#   'a_team': 'Cordoba',
#   'h_goals': '5',
#   'a_goals': '0',
#   'date': '2014-12-20 15:00:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '35645',
#   'minute': '81',
#   'result': 'Goal',
#   'X': '0.865',
#   'Y': '0.48',
#   'xG': '0.07197590172290802',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'FromCorner',
#   'season': '2014',
#   'shotType': 'RightFoot',
#   'match_id': '5708',
#   'h_team': 'Barcelona',
#   'a_team': 'Cordoba',
#   'h_goals': '5',
#   'a_goals': '0',
#   'date': '2014-12-20 15:00:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '35647',
#   'minute': '90',
#   'result': 'Goal',
#   'X': '0.9059999847412109',
#   'Y': '0.38799999237060545',
#   'xG': '0.09458550065755844',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'RightFoot',
#   'match_id': '5708',
#   'h_team': 'Barcelona',
#   'a_team': 'Cordoba',
#   'h_goals': '5',
#   'a_goals': '0',
#   'date': '2014-12-20 15:00:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '37590',
#   'minute': '64',
#   'result': 'MissedShots',
#   'X': '0.7280000305175781',
#   'Y': '0.5820000076293945',
#   'xG': '0.05423299968242645',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'DirectFreekick',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5650',
#   'h_team': 'Real Sociedad',
#   'a_team': 'Barcelona',
#   'h_goals': '1',
#   'a_goals': '0',
#   'date': '2015-01-04 20:00:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '37592',
#   'minute': '70',
#   'result': 'MissedShots',
#   'X': '0.8159999847412109',
#   'Y': '0.525',
#   'xG': '0.048288799822330475',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5650',
#   'h_team': 'Real Sociedad',
#   'a_team': 'Barcelona',
#   'h_goals': '1',
#   'a_goals': '0',
#   'date': '2015-01-04 20:00:00',
#   'player_assisted': 'Luis Suárez',
#   'lastAction': 'Pass'},
#  {'id': '38269',
#   'minute': '8',
#   'result': 'MissedShots',
#   'X': '0.9330000305175781',
#   'Y': '0.31799999237060544',
#   'xG': '0.0867512971162796',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'RightFoot',
#   'match_id': '5660',
#   'h_team': 'Barcelona',
#   'a_team': 'Atletico Madrid',
#   'h_goals': '3',
#   'a_goals': '1',
#   'date': '2015-01-11 20:00:00',
#   'player_assisted': 'Neymar',
#   'lastAction': 'TakeOn'},
#  {'id': '38278',
#   'minute': '28',
#   'result': 'SavedShot',
#   'X': '0.965999984741211',
#   'Y': '0.34700000762939454',
#   'xG': '0.16071699559688568',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'RightFoot',
#   'match_id': '5660',
#   'h_team': 'Barcelona',
#   'a_team': 'Atletico Madrid',
#   'h_goals': '3',
#   'a_goals': '1',
#   'date': '2015-01-11 20:00:00',
#   'player_assisted': 'Neymar',
#   'lastAction': 'TakeOn'},
#  {'id': '38280',
#   'minute': '41',
#   'result': 'MissedShots',
#   'X': '0.8730000305175781',
#   'Y': '0.5059999847412109',
#   'xG': '0.04980729892849922',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'Head',
#   'match_id': '5660',
#   'h_team': 'Barcelona',
#   'a_team': 'Atletico Madrid',
#   'h_goals': '3',
#   'a_goals': '1',
#   'date': '2015-01-11 20:00:00',
#   'player_assisted': 'Dani Alves',
#   'lastAction': 'Chipped'},
#  {'id': '38285',
#   'minute': '63',
#   'result': 'BlockedShot',
#   'X': '0.895',
#   'Y': '0.5279999923706055',
#   'xG': '0.13986900448799133',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5660',
#   'h_team': 'Barcelona',
#   'a_team': 'Atletico Madrid',
#   'h_goals': '3',
#   'a_goals': '1',
#   'date': '2015-01-11 20:00:00',
#   'player_assisted': None,
#   'lastAction': 'Rebound'},
#  {'id': '38286',
#   'minute': '65',
#   'result': 'BlockedShot',
#   'X': '0.7319999694824219',
#   'Y': '0.5529999923706055',
#   'xG': '0.05870179831981659',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'DirectFreekick',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5660',
#   'h_team': 'Barcelona',
#   'a_team': 'Atletico Madrid',
#   'h_goals': '3',
#   'a_goals': '1',
#   'date': '2015-01-11 20:00:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '38288',
#   'minute': '83',
#   'result': 'SavedShot',
#   'X': '0.8180000305175781',
#   'Y': '0.4470000076293945',
#   'xG': '0.0712399035692215',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5660',
#   'h_team': 'Barcelona',
#   'a_team': 'Atletico Madrid',
#   'h_goals': '3',
#   'a_goals': '1',
#   'date': '2015-01-11 20:00:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '38290',
#   'minute': '86',
#   'result': 'Goal',
#   'X': '0.93',
#   'Y': '0.4640000152587891',
#   'xG': '0.5731120109558105',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5660',
#   'h_team': 'Barcelona',
#   'a_team': 'Atletico Madrid',
#   'h_goals': '3',
#   'a_goals': '1',
#   'date': '2015-01-11 20:00:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '37502',
#   'minute': '9',
#   'result': 'Goal',
#   'X': '0.8819999694824219',
#   'Y': '0.5790000152587891',
#   'xG': '0.039577700197696686',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'Head',
#   'match_id': '5669',
#   'h_team': 'Deportivo La Coruna',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '4',
#   'date': '2015-01-18 18:00:00',
#   'player_assisted': 'Ivan Rakitic',
#   'lastAction': 'Chipped'},
#  {'id': '37501',
#   'minute': '9',
#   'result': 'SavedShot',
#   'X': '0.879000015258789',
#   'Y': '0.5329999923706055',
#   'xG': '0.13854099810123444',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'FromCorner',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5669',
#   'h_team': 'Deportivo La Coruna',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '4',
#   'date': '2015-01-18 18:00:00',
#   'player_assisted': 'Ivan Rakitic',
#   'lastAction': 'Cross'},
#  {'id': '37506',
#   'minute': '32',
#   'result': 'Goal',
#   'X': '0.9540000152587891',
#   'Y': '0.5479999923706055',
#   'xG': '0.9347590208053589',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5669',
#   'h_team': 'Deportivo La Coruna',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '4',
#   'date': '2015-01-18 18:00:00',
#   'player_assisted': 'Luis Suárez',
#   'lastAction': 'TakeOn'},
#  {'id': '37508',
#   'minute': '34',
#   'result': 'MissedShots',
#   'X': '0.899000015258789',
#   'Y': '0.34400001525878904',
#   'xG': '0.08937530219554901',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'RightFoot',
#   'match_id': '5669',
#   'h_team': 'Deportivo La Coruna',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '4',
#   'date': '2015-01-18 18:00:00',
#   'player_assisted': 'Sergio Busquets',
#   'lastAction': 'Pass'},
#  {'id': '37514',
#   'minute': '61',
#   'result': 'Goal',
#   'X': '0.885',
#   'Y': '0.32799999237060545',
#   'xG': '0.04759810119867325',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'FromCorner',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5669',
#   'h_team': 'Deportivo La Coruna',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '4',
#   'date': '2015-01-18 18:00:00',
#   'player_assisted': 'Ivan Rakitic',
#   'lastAction': 'Pass'},
#  {'id': '37516',
#   'minute': '64',
#   'result': 'MissedShots',
#   'X': '0.7759999847412109',
#   'Y': '0.285',
#   'xG': '0.05836920067667961',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'DirectFreekick',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5669',
#   'h_team': 'Deportivo La Coruna',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '4',
#   'date': '2015-01-18 18:00:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '37519',
#   'minute': '76',
#   'result': 'BlockedShot',
#   'X': '0.9069999694824219',
#   'Y': '0.504000015258789',
#   'xG': '0.13519300520420074',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5669',
#   'h_team': 'Deportivo La Coruna',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '4',
#   'date': '2015-01-18 18:00:00',
#   'player_assisted': 'Luis Suárez',
#   'lastAction': 'Cross'},
#  {'id': '37961',
#   'minute': '20',
#   'result': 'MissedShots',
#   'X': '0.7659999847412109',
#   'Y': '0.255',
#   'xG': '0.04776500165462494',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'DirectFreekick',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5673',
#   'h_team': 'Elche',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '6',
#   'date': '2015-01-24 17:00:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '37966',
#   'minute': '54',
#   'result': 'Goal',
#   'X': '0.885',
#   'Y': '0.5',
#   'xG': '0.7432780265808105',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'Penalty',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5673',
#   'h_team': 'Elche',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '6',
#   'date': '2015-01-24 17:00:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '37973',
#   'minute': '79',
#   'result': 'SavedShot',
#   'X': '0.7340000152587891',
#   'Y': '0.500999984741211',
#   'xG': '0.06168980151414871',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'DirectFreekick',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5673',
#   'h_team': 'Elche',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '6',
#   'date': '2015-01-24 17:00:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '37974',
#   'minute': '87',
#   'result': 'Goal',
#   'X': '0.875',
#   'Y': '0.6179999923706054',
#   'xG': '0.09191279858350754',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5673',
#   'h_team': 'Elche',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '6',
#   'date': '2015-01-24 17:00:00',
#   'player_assisted': 'Marc Bartra',
#   'lastAction': 'Pass'},
#  {'id': '40854',
#   'minute': '18',
#   'result': 'BlockedShot',
#   'X': '0.7980000305175782',
#   'Y': '0.5629999923706055',
#   'xG': '0.12279599905014038',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'DirectFreekick',
#   'season': '2014',
#   'shotType': 'LeftFoot',
#   'match_id': '5605',
#   'h_team': 'Barcelona',
#   'a_team': 'Villarreal',
#   'h_goals': '3',
#   'a_goals': '2',
#   'date': '2015-02-01 20:00:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '40868',
#   'minute': '52',
#   'result': 'BlockedShot',
#   'X': '0.93',
#   'Y': '0.515',
#   'xG': '0.06194249913096428',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'Head',
#   'match_id': '5605',
#   'h_team': 'Barcelona',
#   'a_team': 'Villarreal',
#   'h_goals': '3',
#   'a_goals': '2',
#   'date': '2015-02-01 20:00:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '40870',
#   'minute': '54',
#   'result': 'Goal',
#   'X': '0.815',
#   'Y': '0.48900001525878906',
#   'xG': '0.0639675036072731',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2014',
#   'shotType': 'RightFoot',
#   'match_id': '5605',
#   'h_team': 'Barcelona',
#   'a_team': 'Villarreal',
#   'h_goals': '3',
#   'a_goals': '2',
#   'date': '2015-02-01 20:00:00',
# ...
#   'Y': '0.47200000762939454',
#   'xG': '0.08034689724445343',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12233',
#   'h_team': 'Barcelona',
#   'a_team': 'Levante',
#   'h_goals': '2',
#   'a_goals': '1',
#   'date': '2020-02-02 20:00:00',
#   'player_assisted': 'Sergi Roberto',
#   'lastAction': 'Pass'},
#  {'id': '357441',
#   'minute': '73',
#   'result': 'SavedShot',
#   'X': '0.9490000152587891',
#   'Y': '0.3609999847412109',
#   'xG': '0.23972000181674957',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12233',
#   'h_team': 'Barcelona',
#   'a_team': 'Levante',
#   'h_goals': '2',
#   'a_goals': '1',
#   'date': '2020-02-02 20:00:00',
#   'player_assisted': None,
#   'lastAction': 'TakeOn'},
#  {'id': '357442',
#   'minute': '76',
#   'result': 'BlockedShot',
#   'X': '0.8169999694824219',
#   'Y': '0.5359999847412109',
#   'xG': '0.09102760255336761',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12233',
#   'h_team': 'Barcelona',
#   'a_team': 'Levante',
#   'h_goals': '2',
#   'a_goals': '1',
#   'date': '2020-02-02 20:00:00',
#   'player_assisted': 'Sergio Busquets',
#   'lastAction': 'TakeOn'},
#  {'id': '357446',
#   'minute': '89',
#   'result': 'MissedShots',
#   'X': '0.875999984741211',
#   'Y': '0.5940000152587891',
#   'xG': '0.12419799715280533',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12233',
#   'h_team': 'Barcelona',
#   'a_team': 'Levante',
#   'h_goals': '2',
#   'a_goals': '1',
#   'date': '2020-02-02 20:00:00',
#   'player_assisted': 'Sergi Roberto',
#   'lastAction': 'Pass'},
#  {'id': '358677',
#   'minute': '22',
#   'result': 'SavedShot',
#   'X': '0.925',
#   'Y': '0.43099998474121093',
#   'xG': '0.4761529862880707',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12251',
#   'h_team': 'Real Betis',
#   'a_team': 'Barcelona',
#   'h_goals': '2',
#   'a_goals': '3',
#   'date': '2020-02-09 20:00:00',
#   'player_assisted': 'Antoine Griezmann',
#   'lastAction': 'Throughball'},
#  {'id': '358682',
#   'minute': '46',
#   'result': 'SavedShot',
#   'X': '0.855',
#   'Y': '0.46799999237060547',
#   'xG': '0.09480810165405273',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12251',
#   'h_team': 'Real Betis',
#   'a_team': 'Barcelona',
#   'h_goals': '2',
#   'a_goals': '3',
#   'date': '2020-02-09 20:00:00',
#   'player_assisted': 'Arturo Vidal',
#   'lastAction': 'Pass'},
#  {'id': '358684',
#   'minute': '61',
#   'result': 'SavedShot',
#   'X': '0.8780000305175781',
#   'Y': '0.40799999237060547',
#   'xG': '0.11155799776315689',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12251',
#   'h_team': 'Real Betis',
#   'a_team': 'Barcelona',
#   'h_goals': '2',
#   'a_goals': '3',
#   'date': '2020-02-09 20:00:00',
#   'player_assisted': 'Jordi Alba',
#   'lastAction': 'TakeOn'},
#  {'id': '358685',
#   'minute': '66',
#   'result': 'MissedShots',
#   'X': '0.8690000152587891',
#   'Y': '0.6969999694824218',
#   'xG': '0.04554019868373871',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12251',
#   'h_team': 'Real Betis',
#   'a_team': 'Barcelona',
#   'h_goals': '2',
#   'a_goals': '3',
#   'date': '2020-02-09 20:00:00',
#   'player_assisted': 'Jordi Alba',
#   'lastAction': 'Pass'},
#  {'id': '358983',
#   'minute': '11',
#   'result': 'BlockedShot',
#   'X': '0.75',
#   'Y': '0.40700000762939453',
#   'xG': '0.020945100113749504',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12254',
#   'h_team': 'Barcelona',
#   'a_team': 'Getafe',
#   'h_goals': '2',
#   'a_goals': '1',
#   'date': '2020-02-15 15:00:00',
#   'player_assisted': 'Sergi Roberto',
#   'lastAction': 'Pass'},
#  {'id': '358984',
#   'minute': '13',
#   'result': 'SavedShot',
#   'X': '0.8119999694824219',
#   'Y': '0.46799999237060547',
#   'xG': '0.31642401218414307',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12254',
#   'h_team': 'Barcelona',
#   'a_team': 'Getafe',
#   'h_goals': '2',
#   'a_goals': '1',
#   'date': '2020-02-15 15:00:00',
#   'player_assisted': 'Sergio Busquets',
#   'lastAction': 'Throughball'},
#  {'id': '358989',
#   'minute': '42',
#   'result': 'MissedShots',
#   'X': '0.6969999694824218',
#   'Y': '0.46299999237060546',
#   'xG': '0.04164909943938255',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'DirectFreekick',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12254',
#   'h_team': 'Barcelona',
#   'a_team': 'Getafe',
#   'h_goals': '2',
#   'a_goals': '1',
#   'date': '2020-02-15 15:00:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '358990',
#   'minute': '47',
#   'result': 'SavedShot',
#   'X': '0.9230000305175782',
#   'Y': '0.555',
#   'xG': '0.2254759967327118',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'Head',
#   'match_id': '12254',
#   'h_team': 'Barcelona',
#   'a_team': 'Getafe',
#   'h_goals': '2',
#   'a_goals': '1',
#   'date': '2020-02-15 15:00:00',
#   'player_assisted': 'Antoine Griezmann',
#   'lastAction': 'Cross'},
#  {'id': '358992',
#   'minute': '58',
#   'result': 'BlockedShot',
#   'X': '0.965999984741211',
#   'Y': '0.34599998474121096',
#   'xG': '0.11320199817419052',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12254',
#   'h_team': 'Barcelona',
#   'a_team': 'Getafe',
#   'h_goals': '2',
#   'a_goals': '1',
#   'date': '2020-02-15 15:00:00',
#   'player_assisted': 'Anssumane Fati',
#   'lastAction': 'Pass'},
#  {'id': '359001',
#   'minute': '89',
#   'result': 'MissedShots',
#   'X': '0.7869999694824219',
#   'Y': '0.3160000038146973',
#   'xG': '0.018065400421619415',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12254',
#   'h_team': 'Barcelona',
#   'a_team': 'Getafe',
#   'h_goals': '2',
#   'a_goals': '1',
#   'date': '2020-02-15 15:00:00',
#   'player_assisted': 'Sergi Roberto',
#   'lastAction': 'TakeOn'},
#  {'id': '359885',
#   'minute': '13',
#   'result': 'Goal',
#   'X': '0.875',
#   'Y': '0.5459999847412109',
#   'xG': '0.39785000681877136',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12265',
#   'h_team': 'Barcelona',
#   'a_team': 'Eibar',
#   'h_goals': '5',
#   'a_goals': '0',
#   'date': '2020-02-22 15:00:00',
#   'player_assisted': 'Ivan Rakitic',
#   'lastAction': 'TakeOn'},
#  {'id': '359891',
#   'minute': '36',
#   'result': 'Goal',
#   'X': '0.9169999694824219',
#   'Y': '0.655',
#   'xG': '0.3399600088596344',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12265',
#   'h_team': 'Barcelona',
#   'a_team': 'Eibar',
#   'h_goals': '5',
#   'a_goals': '0',
#   'date': '2020-02-22 15:00:00',
#   'player_assisted': 'Arturo Vidal',
#   'lastAction': 'Pass'},
#  {'id': '359892',
#   'minute': '39',
#   'result': 'Goal',
#   'X': '0.91',
#   'Y': '0.46799999237060547',
#   'xG': '0.45305299758911133',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12265',
#   'h_team': 'Barcelona',
#   'a_team': 'Eibar',
#   'h_goals': '5',
#   'a_goals': '0',
#   'date': '2020-02-22 15:00:00',
#   'player_assisted': None,
#   'lastAction': 'Dispossessed'},
#  {'id': '359904',
#   'minute': '78',
#   'result': 'SavedShot',
#   'X': '0.7280000305175781',
#   'Y': '0.5279999923706055',
#   'xG': '0.057382501661777496',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'DirectFreekick',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12265',
#   'h_team': 'Barcelona',
#   'a_team': 'Eibar',
#   'h_goals': '5',
#   'a_goals': '0',
#   'date': '2020-02-22 15:00:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '359905',
#   'minute': '86',
#   'result': 'Goal',
#   'X': '0.9630000305175781',
#   'Y': '0.544000015258789',
#   'xG': '0.6275069713592529',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12265',
#   'h_team': 'Barcelona',
#   'a_team': 'Eibar',
#   'h_goals': '5',
#   'a_goals': '0',
#   'date': '2020-02-22 15:00:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '361464',
#   'minute': '29',
#   'result': 'SavedShot',
#   'X': '0.8830000305175781',
#   'Y': '0.37099998474121093',
#   'xG': '0.08147680014371872',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12279',
#   'h_team': 'Real Madrid',
#   'a_team': 'Barcelona',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2020-03-01 20:00:00',
#   'player_assisted': 'Antoine Griezmann',
#   'lastAction': 'Pass'},
#  {'id': '361469',
#   'minute': '37',
#   'result': 'SavedShot',
#   'X': '0.845',
#   'Y': '0.4879999923706055',
#   'xG': '0.2814039885997772',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12279',
#   'h_team': 'Real Madrid',
#   'a_team': 'Barcelona',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2020-03-01 20:00:00',
#   'player_assisted': 'Sergio Busquets',
#   'lastAction': 'Chipped'},
#  {'id': '361471',
#   'minute': '46',
#   'result': 'BlockedShot',
#   'X': '0.8540000152587891',
#   'Y': '0.6819999694824219',
#   'xG': '0.06603489816188812',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12279',
#   'h_team': 'Real Madrid',
#   'a_team': 'Barcelona',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2020-03-01 20:00:00',
#   'player_assisted': 'Frenkie de Jong',
#   'lastAction': 'TakeOn'},
#  {'id': '361805',
#   'minute': '28',
#   'result': 'SavedShot',
#   'X': '0.9640000152587891',
#   'Y': '0.615',
#   'xG': '0.29125601053237915',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12285',
#   'h_team': 'Barcelona',
#   'a_team': 'Real Sociedad',
#   'h_goals': '1',
#   'a_goals': '0',
#   'date': '2020-03-07 17:30:00',
#   'player_assisted': 'Sergio Busquets',
#   'lastAction': 'Chipped'},
#  {'id': '361810',
#   'minute': '39',
#   'result': 'MissedShots',
#   'X': '0.865',
#   'Y': '0.565',
#   'xG': '0.0982310026884079',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12285',
#   'h_team': 'Barcelona',
#   'a_team': 'Real Sociedad',
#   'h_goals': '1',
#   'a_goals': '0',
#   'date': '2020-03-07 17:30:00',
#   'player_assisted': 'Frenkie de Jong',
#   'lastAction': 'Pass'},
#  {'id': '361812',
#   'minute': '53',
#   'result': 'MissedShots',
#   'X': '0.8290000152587891',
#   'Y': '0.48900001525878906',
#   'xG': '0.08789580315351486',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12285',
#   'h_team': 'Barcelona',
#   'a_team': 'Real Sociedad',
#   'h_goals': '1',
#   'a_goals': '0',
#   'date': '2020-03-07 17:30:00',
#   'player_assisted': 'Jordi Alba',
#   'lastAction': 'TakeOn'},
#  {'id': '361814',
#   'minute': '56',
#   'result': 'BlockedShot',
#   'X': '0.7519999694824219',
#   'Y': '0.625999984741211',
#   'xG': '0.06327860057353973',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'DirectFreekick',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12285',
#   'h_team': 'Barcelona',
#   'a_team': 'Real Sociedad',
#   'h_goals': '1',
#   'a_goals': '0',
#   'date': '2020-03-07 17:30:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '361816',
#   'minute': '59',
#   'result': 'MissedShots',
#   'X': '0.9230000305175782',
#   'Y': '0.5459999847412109',
#   'xG': '0.09510389715433121',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12285',
#   'h_team': 'Barcelona',
#   'a_team': 'Real Sociedad',
#   'h_goals': '1',
#   'a_goals': '0',
#   'date': '2020-03-07 17:30:00',
#   'player_assisted': 'Antoine Griezmann',
#   'lastAction': 'HeadPass'},
#  {'id': '361821',
#   'minute': '80',
#   'result': 'Goal',
#   'X': '0.885',
#   'Y': '0.5',
#   'xG': '0.7432780265808105',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'Penalty',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12285',
#   'h_team': 'Barcelona',
#   'a_team': 'Real Sociedad',
#   'h_goals': '1',
#   'a_goals': '0',
#   'date': '2020-03-07 17:30:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '364341',
#   'minute': '11',
#   'result': 'BlockedShot',
#   'X': '0.895',
#   'Y': '0.605',
#   'xG': '0.11926399916410446',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12297',
#   'h_team': 'Mallorca',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '4',
#   'date': '2020-06-13 20:00:00',
#   'player_assisted': 'Antoine Griezmann',
#   'lastAction': 'Pass'},
#  {'id': '364354',
#   'minute': '65',
#   'result': 'MissedShots',
#   'X': '0.9209999847412109',
#   'Y': '0.6480000305175782',
#   'xG': '0.11432699859142303',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12297',
#   'h_team': 'Mallorca',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '4',
#   'date': '2020-06-13 20:00:00',
#   'player_assisted': 'Ivan Rakitic',
#   'lastAction': 'Pass'},
#  {'id': '364361',
#   'minute': '92',
#   'result': 'Goal',
#   'X': '0.8669999694824219',
#   'Y': '0.5479999923706055',
#   'xG': '0.1170480027794838',
#   'player': 'Lionel Messi',
#   'h_a': 'a',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12297',
#   'h_team': 'Mallorca',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '4',
#   'date': '2020-06-13 20:00:00',
#   'player_assisted': 'Luis Suárez',
#   'lastAction': 'Pass'},
#  {'id': '364666',
#   'minute': '43',
#   'result': 'MissedShots',
#   'X': '0.9209999847412109',
#   'Y': '0.515',
#   'xG': '0.08428219705820084',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'Head',
#   'match_id': '12307',
#   'h_team': 'Barcelona',
#   'a_team': 'Leganes',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2020-06-16 20:00:00',
#   'player_assisted': 'Sergi Roberto',
#   'lastAction': 'Aerial'},
#  {'id': '364667',
#   'minute': '50',
#   'result': 'SavedShot',
#   'X': '0.7319999694824219',
#   'Y': '0.32799999237060545',
#   'xG': '0.046184200793504715',
#   'player': 'Lionel Messi',
#   'h_a': 'h',
#   'player_id': '2097',
#   'situation': 'DirectFreekick',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12307',
#   'h_team': 'Barcelona',
#   'a_team': 'Leganes',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2020-06-16 20:00:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  ...]

# %%
print(len(data))
# Out:
# 1462

# %%
### DATA CLEANING ###

X = []
Y = []
xG = []
situation = []
shotType = []
h_a = []
h_team = []
a_team = []
date = []
result = []
player = []
season = []


for index in range(len(data)):
    for key in data[index]:
        if key == 'X':
            X.append(data[index][key])
        if key == 'Y':
            Y.append(data[index][key])
        if key == 'situation':
            situation.append(data[index][key])
        if key == 'shotType':
            shotType.append(data[index][key])
        if key == 'h_team':
            h_team.append(data[index][key])
        if key == 'a_team':
            a_team.append(data[index][key])
        if key == 'xG':
            xG.append(data[index][key])
        if key == 'player':
            player.append(data[index][key])
        if key == 'result':
            result.append(data[index][key])
        if key == 'h_a':
            h_a.append(data[index][key])
        if key == 'season':
            season.append(data[index][key])

            


col_names = ['X','Y','result','xG','situation','shotType','h_team','a_team','h_a','season']
df = pd.DataFrame([X,Y,result,xG,situation,shotType,h_team,a_team,h_a,season],index=col_names)
df = df.T

convert_dict = {'X': float,
                'Y': float,
                'xG': float,
                }

df = df.astype(convert_dict)
df = df
#print(df.dtypes)

fig, ax = plt.subplots(figsize=(13,8.5))

#pitch = Pitch(pitch_type='statsbomb')

ax.scatter(df['X']*120,df['Y']*80,s=df['xG']*300)
plt.ylim(0,80)
plt.xlim(0,120)


df_fk = df.loc[df['situation']=='DirectFreekick']
fk_saved = len(df_fk.loc[df['result'] == 'SavedShot'])
fk_goals = len(df_fk.loc[df['result'] == 'Goal'])
fk_OnTarget = fk_saved + fk_goals
df_fk_goals = df_fk.loc[df['result']=='Goal']
xG_cum = df_fk['xG'].cumsum()
xG_tot = xG_cum.iat[-1]
xG_tot = round(xG_tot, 2)

print(fk_OnTarget)
# Out:
# 109

# %%
print(df_fk)

#pd.to_csv(path_or_'jwp_fk_data_v2',index=False)
# Out:
#           X      Y       result        xG       situation  shotType  \
# 4     0.869  0.192    SavedShot  0.065317  DirectFreekick  LeftFoot
# 5     0.723  0.494    SavedShot  0.054805  DirectFreekick  LeftFoot
# 16    0.762  0.310  MissedShots  0.056991  DirectFreekick  LeftFoot
# 23    0.766  0.612  MissedShots  0.075770  DirectFreekick  LeftFoot
# 39    0.768  0.318  BlockedShot  0.061873  DirectFreekick  LeftFoot
# ...     ...    ...          ...       ...             ...       ...
# 1425  0.802  0.495  BlockedShot  0.136140  DirectFreekick  LeftFoot
# 1448  0.820  0.683  BlockedShot  0.091932  DirectFreekick  LeftFoot
# 1454  0.753  0.515  MissedShots  0.070301  DirectFreekick  LeftFoot
# 1458  0.759  0.358  MissedShots  0.059618  DirectFreekick  LeftFoot
# 1461  0.718  0.395    SavedShot  0.043179  DirectFreekick  LeftFoot
#
#                    h_team               a_team h_a season
# 4              Villarreal            Barcelona   a   2014
# 5              Villarreal            Barcelona   a   2014
# 16                 Malaga            Barcelona   a   2014
# 23         Rayo Vallecano            Barcelona   a   2014
# 39            Real Madrid            Barcelona   a   2014
# ...                   ...                  ...  ..    ...
# 1425                Brest  Paris Saint Germain   a   2022
# 1448  Paris Saint Germain              Ajaccio   h   2022
# 1454           Strasbourg  Paris Saint Germain   a   2022
# 1458  Paris Saint Germain        Clermont Foot   h   2022
# 1461  Paris Saint Germain        Clermont Foot   h   2022
#
# [320 rows x 10 columns]

# %%
#### PLOTTING #####


fig, ax = plt.subplots(figsize=(13,8.5))

#fig.set_facecolor('#22312b')
#ax.patch.set_facecolor('#22312b')
#plt.ylim(5,80)
#plt.xlim(0,120)

pitch = pitch = VerticalPitch(half=True,goal_type='box',line_color='black')
pitch.draw(ax=ax)
#plt.gca().invert_yaxis()
plt.gca().invert_xaxis()

ax.set_title('James Ward-Prowse | Direct Free Kick Attempts | EPL since 14/15',fontsize=17)

for x in range(len(df['X'])):
        if df['situation'][x] == 'DirectFreekick':
            if df['result'][x] == 'Goal': 
                plt.scatter(df['Y'][x]*79,df['X'][x]*123, color = '#39FF14',s=df['xG'][x]*1000,zorder=2,alpha=.9,label="Goal")
            if df['result'][x] == 'SavedShot':
                plt.scatter(df['Y'][x]*79,df['X'][x]*123, color = '#FFFF00',s=df['xG'][x]*1000,zorder=2,alpha=.9,label="Saved")
            else:
                plt.scatter(df['Y'][x]*79,df['X'][x]*123, color = '#DFDFDF',s=df['xG'][x]*1000,zorder=1,alpha=.9, label="Off Target")
            

              
fig.text(0.23,0.29,"Attempts: ",fontsize=14)
fig.text(0.31,0.29,str(len(df_fk)),fontsize=14)
fig.text(0.23,0.265,"On Target: ",fontsize=14)
fig.text(0.31,0.265,str(fk_OnTarget),fontsize=14)
fig.text(0.23,0.24,"Goals: ",fontsize=14)
fig.text(0.31,0.24,str(fk_goals),fontsize=14)
fig.text(0.23,0.215,"Total xG:",fontsize=14)
fig.text(0.31,0.215,str(xG_tot),fontsize=14)
fig.text(0.23,0.19,"Diff:",fontsize=14)
fig.text(0.31,0.19,str(fk_goals-xG_tot)+'+',fontsize=14, color='green')



#ax.legend()
# Out:
# Text(0.31, 0.19, '7.359999999999999+')

# %%
fig, ax = plt.subplots(figsize=(13,8.5))




kde = sns.kdeplot(
    df_fk['Y']*79,
    df_fk['X']*122,
    fill=True,
    shade_lowest=False,
    alpha=1,
    n_levels=20,
    cmap='viridis'
)


pitch = VerticalPitch(half=True, goal_type='box')
pitch.draw(ax=ax)
#plt.gca().invert_yaxis()
plt.gca().invert_xaxis()


## Opaque box for freelkick heatmap
box_18 = patches.Rectangle((18, 102), 44, 18, linewidth=1.5, edgecolor='lightgrey', facecolor='#22312b')
box_6 = patches.Rectangle((30, 114), 20, 6, linewidth=1.5, edgecolor='lightgrey', facecolor='#22312b')
ax.add_patch(box_18)
ax.add_patch(box_6)

fig.set_facecolor('#22312b')
ax.patch.set_facecolor('#22312b')

#plt.scatter(df_fk['X'],df_fk['Y'])
# Out:
# /opt/anaconda3/envs/f1/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig, ax = plt.subplots(figsize=(13,8.5))

#fig.set_facecolor('#22312b')
#ax.patch.set_facecolor('#22312b')
#plt.ylim(5,80)
#plt.xlim(0,120)


kde = sns.kdeplot(
    df_fk_goals['Y']*79,
    df_fk_goals['X']*122,
    fill=True,
    shade_lowest=False,
    alpha=1,
    n_levels=10,
    cmap='inferno'
)



pitch = pitch = VerticalPitch(half=True, goal_type='box', line_color='white', linewidth=4)
pitch.draw(ax=ax)
#plt.gca().invert_yaxis()
plt.gca().invert_xaxis()

box_18 = patches.Rectangle((18, 102), 44, 18, linewidth=4, edgecolor='white', facecolor='black')
box_6 = patches.Rectangle((30, 114), 20, 6, linewidth=4, edgecolor='white', facecolor='black')
ax.add_patch(box_18)
ax.add_patch(box_6)

fig.set_facecolor('black')
ax.patch.set_facecolor('black')
# Out:
# /opt/anaconda3/envs/f1/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
layout = [["scatter", "heat_a"],
          ["scatter", "heat_b"]]

fig = plt.figure(figsize = (15,8))

ax_dict = fig.subplot_mosaic(
    layout
)

ax_dict["scatter"].annotate(
    xy = (.5,.5),
    text = "scatter",
    ha = "center",
    va = "center",
    size = 20
)

ax_dict["heat_a"].annotate(
    xy = (.5,.5),
    text = "heat_b",
    ha = "center",
    va = "center",
    size = 20
)

ax_dict["heat_b"].annotate(
    xy = (.5,.5),
    text = "heat_b",
    ha = "center",
    va = "center",
    size = 20
)
# Out:
# Text(0.5, 0.5, 'heat_b')

# %%
fig, ax = plt.subplots(figsize=(13,8.5))

#fig.set_facecolor('#22312b')
#ax.patch.set_facecolor('#22312b')
#plt.ylim(5,80)
#plt.xlim(0,120)


kde2 = sns.kdeplot(
    df_fk_goals['Y']*79,
    df_fk_goals['X']*122,
    fill=True,
    shade_lowest=False,
    alpha=1,
    n_levels=10,
    cmap='inferno',

)

for x in range(len(df['X'])):
        if df['situation'][x] == 'DirectFreekick':
            if df['result'][x] == 'Goal': 
                plt.scatter(df['Y'][x]*79,df['X'][x]*123, color = '#39FF14', edgecolor='black',zorder=2,alpha=1,label="Goal")

pitch = pitch = VerticalPitch(half=True, goal_type='box')
pitch.draw(ax=ax)
#plt.gca().invert_yaxis()
plt.gca().invert_xaxis()

box_18 = patches.Rectangle((18, 102), 44, 18, linewidth=1.5, edgecolor='lightgrey', facecolor='#22312b')
box_6 = patches.Rectangle((30, 114), 20, 6, linewidth=1.5, edgecolor='lightgrey', facecolor='#22312b')
ax.add_patch(box_18)
ax.add_patch(box_6)

fig.set_facecolor('#22312b')
ax.patch.set_facecolor('#22312b')
# Out:
# /opt/anaconda3/envs/f1/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig, ax = plt.subplots(figsize=(13,8.5))




kde = sns.kdeplot(
    df_fk['Y']*79,
    df_fk['X']*122,
    fill=True,
    shade_lowest=False,
    alpha=1,
    n_levels=30,
    cmap='viridis'
)

            
for x in range(len(df['X'])):
        if df['situation'][x] == 'DirectFreekick':
            if df['result'][x] == 'Goal': 
                plt.scatter(df['Y'][x]*79,df['X'][x]*123, color = '#39FF14',zorder=2,alpha=1)
            else:
                plt.scatter(df['Y'][x]*79,df['X'][x]*123, color = 'none', edgecolor= '#39FF14',zorder=2,alpha=1)

pitch = VerticalPitch(half=True, goal_type='box')
pitch.draw(ax=ax)
#plt.gca().invert_yaxis()
plt.gca().invert_xaxis()


## Opaque box for freelkick heatmap
box_18 = patches.Rectangle((18, 102), 44, 18, linewidth=1.5, edgecolor='lightgrey', facecolor='#22312b')
box_6 = patches.Rectangle((30, 114), 20, 6, linewidth=1.5, edgecolor='lightgrey', facecolor='#22312b')
ax.add_patch(box_18)
ax.add_patch(box_6)

fig.set_facecolor('#22312b')
ax.patch.set_facecolor('#22312b')
# Out:
# /opt/anaconda3/envs/f1/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_fk['Xi'] = df_fk['Y']*68
df_fk['Yi'] = df_fk['X']*105
# Out:
# /opt/anaconda3/envs/f1/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
df_fk

df_fk.to_csv('data/JWP_FK_v2.csv')

# %%
def soc_pitch_divisions(ax, grids = False):
    '''
    This function returns a vertical football pitch
    divided in specific locations.

    Args:
        ax (obj): a matplotlib axes.
        grids (bool): should we draw the grid lines?
    '''

    # Notice the extra parameters passed to the object
    pitch = VerticalPitch(
        pitch_type = "uefa",
        half = True,
        goal_type='box',
        linewidth = 1.25,
        line_color='black'
    )

    pitch.draw(ax = ax)

    # Where we'll draw the lines
    if grids:
        y_lines = [105 - 5.5*x for x in range(1,10)]
        x_lines = [68 - 6.8*x for x in range(1,10)]

        for i in x_lines:
            ax.plot(
                [i, i], [45, 105], 
                color = "lightgray", 
                ls = "--",
                lw = 0.75,
                zorder = -1
            )
        for j in y_lines:
            ax.plot(
                [68, 0], [j, j],
                color = "lightgray", 
                ls = "--",
                lw = 0.75,
                zorder = -1
            )

    return ax

# %%
# We define the cuts for our data (same as our pitch divisions)
# Only difference is we need to add the edges

y_bins = [105] + [105 - 5.5*x for x in range(1,10)] + [45]
x_bins = [68] + [68 - 6.8*x for x in range(1,10)] + [0]

x_bins.sort()
y_bins.sort()

# %%
fig = plt.figure(figsize = (4,4), dpi = 100)
ax = plt.subplot(111)

soc_pitch_divisions(ax, grids = True)

counter = 0
for X, Y in zip(df_fk["bins_x"], df_fk["bins_y"]):
	#This colours our bins
    ax.fill_between(
        x = [X.left, X.right],
        y1 = Y.left,
        y2 = Y.right,
        color = "#495371",
        alpha = example_df["xGOT_scaled"].iloc[counter],
        zorder = -1,
        lw = 0
    )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/envs/f1/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /opt/anaconda3/envs/f1/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/anaconda3/envs/f1/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'bins_x'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/k6/x_xqhvps00xc6pmbf1rrwbxc0000gn/T/ipykernel_33633/1802587343.py in <module>
#       5
#       6 counter = 0
# ----> 7 for X, Y in zip(df_fk["bins_x"], df_fk["bins_y"]):
#       8         #This colours our bins
#       9     ax.fill_between(
#
# /opt/anaconda3/envs/f1/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# /opt/anaconda3/envs/f1/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'bins_x'
